# %% [markdown]
# # Simple RAG简介
#
# 检索增强生成（Retrieval-Augmented Generation，RAG）是一种结合信息检索与生成模型的混合方法。通过引入外部知识，它可以提高语言模型的性能，从而提升准确性与事实正确性。
#
# 在简单的RAG设置中，我们遵循以下步骤：
#
# 1. **数据处理**：加载并预处理文本数据。
# 2. **分块**：将数据拆分为更小的部分，以提高检索性能。
# 3. **嵌入创建**：使用嵌入模型将文本块转换为数值表示。
# 4. **语义搜索**：根据用户查询检索相关的文本块。
# 5. **回复生成**：利用语言模型基于检索到的文本生成回复。
#
# 本笔记本实现了一个简单的RAG方法，评估了模型的回复，并探索了各种改进措施。

# %% [markdown]
# ![image.png](./rag_explanation.svg)

# %% [markdown]
# ## 环境设置
# 首先，我们导入必要的库。

# %%
import fitz # PyMuPDF库，用于处理PDF文件 
import os
import numpy as np
import json
from openai import OpenAI

# %% [markdown]
# ## 从PDF文件中提取文本
# 为了实现RAG（Retrieval-Augmented Generation，检索增强生成），我们首先需要一个文本数据源。在此情况下，我们使用PyMuPDF库从PDF文件中提取文本。

# %%
def extract_text_from_pdf(pdf_path):
    """
    从PDF文件中提取文本并打印前`num_chars`个字符。

    参数:
    pdf_path (str): PDF文件的路径。

    返回:
    str: 从PDF中提取的文本。
    """
    # 打开PDF文件
    mypdf = fitz.open(pdf_path)
    all_text = ""  # 初始化一个空字符串用于存储提取的文本

    # 遍历PDF中的每一页
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]  # 获取页面
        text = page.get_text("text")  # 从页面提取文本
        all_text += text  # 将提取的文本追加到all_text字符串中

    return all_text  # 返回提取的文本

# %% [markdown]
# ## 提取文本的分块
# 在提取文本后，我们将其划分为更小的、相互重叠的块，以提高检索准确性。

# %%
def chunk_text(text, n, overlap):
    """
    将给定的文本分割为长度为 n 的段，并带有指定的重叠字符数。

    参数:
    text (str): 需要分割的文本。
    n (int): 每个片段的字符数量。
    overlap (int): 段与段之间的重叠字符数量。

    返回:
    List[str]: 一个包含文本片段的列表。
    """
    chunks = []  # 初始化一个空列表用于存储片段

    # 使用 (n - overlap) 的步长遍历文本
    for i in range(0, len(text), n - overlap):
        # 将从索引 i 到 i + n 的文本片段添加到 chunks 列表中
        chunks.append(text[i : i + n])

    return chunks  # 返回包含文本片段的列表

# %% [markdown]
# ## 初始化OpenAI API客户端
# 我们初始化OpenAI客户端以生成嵌入向量和回复。

# %%
from dotenv import load_dotenv


load_dotenv()
api_key = os.getenv("DASHSCOPE_API_KEY")

client = OpenAI(
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1", api_key=api_key
)

# %% [markdown]
# ## 从PDF文件中提取和分块文本
# 现在，我们加载PDF文件，提取文本并将其分割为块。

# %%
# 定义PDF文件的路径
pdf_path = "data/AI_Information.pdf"

# 从PDF文件中提取文本
extracted_text = extract_text_from_pdf(pdf_path)

# 将提取的文本分割为每段1000个字符并带有200个字符重叠的片段
text_chunks = chunk_text(extracted_text, 1000, 200)

# 打印生成的文本片段数量
print("Number of text chunks:", len(text_chunks))

# 打印第一个文本片段
print("\nFirst text chunk:")
print(text_chunks[0])
# Out:
# Number of text chunks: 42
#
# First text chunk:
# Understanding Artificial Intelligence
# Chapter 1: Introduction to Artificial Intelligence
# Artificial intelligence (AI) refers to the ability of a digital computer or computer-controlled robot
# to perform tasks commonly associated with intelligent beings. The term is frequently applied to
# the project of developing systems endowed with the intellectual processes characteristic of
# humans, such as the ability to reason, discover meaning, generalize, or learn from past
# experience. Over the past few decades, advancements in computing power and data availability
# have significantly accelerated the development and deployment of AI.
# Historical Context
# The idea of artificial intelligence has existed for centuries, often depicted in myths and fiction.
# However, the formal field of AI research began in the mid-20th century. The Dartmouth Workshop
# in 1956 is widely considered the birthplace of AI. Early AI research focused on problem-solving
# and symbolic methods. The 1980s saw a rise in exp

# %% [markdown]
# ## 创建文本块的嵌入
# 嵌入将文本转换为数值向量，这使得相似性搜索变得高效。

# %%
from openai.types import CreateEmbeddingResponse


def create_embeddings_in_batches(text_chunks, batch_size=10, model="text-embedding-v4"):
    combined_data = []
    total_prompt_tokens = 0

    for i in range(0, len(text_chunks), batch_size):
        batch = text_chunks[i : i + batch_size]
        response = client.embeddings.create(model=model, input=batch)

        # 转换为字典以便处理
        res_dict = response.model_dump()

        for item in res_dict["data"]:
            item["index"] += i
            combined_data.append(item)

        if "usage" in res_dict:
            total_prompt_tokens += res_dict["usage"].get("prompt_tokens", 0)

    # 1. 构造标准的字典结构
    final_dict = {
        "data": combined_data,
        "model": model,
        "object": "list",
        "usage": {
            "prompt_tokens": total_prompt_tokens,
            "total_tokens": total_prompt_tokens,
        },
    }

    # 2. 【关键步骤】将字典转换回官方的 Response 对象
    # 这会递归地将 data 里的字典转为 Embedding 对象，将 usage 转为 Usage 对象
    return CreateEmbeddingResponse(**final_dict)


# --- 现在调用方式依然可以保持不变 ---
response = create_embeddings_in_batches(text_chunks)
print(response.data[0].embedding)  # 成功！不再报错
print(response.usage.total_tokens)  # 成功！
# Out:
# [-0.0725545808672905, 0.10438104718923569, 0.005193902179598808, -0.016050415113568306, -0.05475127324461937, 0.019784841686487198, -0.026171473786234856, 0.0643845722079277, -0.01760515570640564, 0.08663870394229889, -0.02582089602947235, -0.01367257535457611, -0.008185254409909248, -0.03307635337114334, 0.028168249875307083, -0.07035965472459793, 0.032405681908130646, 0.001641433103941381, 0.11968457698822021, -0.00808617752045393, 0.011538617312908173, -0.05706814303994179, 0.018687376752495766, 0.06145799905061722, -0.05124548450112343, 0.03261907771229744, -0.019479990005493164, 0.02550080232322216, 0.02301626466214657, 0.02133958227932453, -0.03399090841412544, -0.028442615643143654, 0.008794956840574741, -0.04606301337480545, 0.002979920245707035, -0.012735158205032349, 0.0049462104216217995, -0.0045765782706439495, -0.022757140919566154, -0.01944950595498085, 0.027009814977645874, 0.0023035318590700626, 0.025516044348478317, -0.027695730328559875, 0.000787373457569629, -0.0024902531877160072, 0.00011961836571572348, -0.057312022894620895, 0.01876359060406685, 0.04417293518781662, 0.0010593578917905688, 0.046276409178972244, 0.0031914107967168093, -0.03362508490681648, 0.055
#         0.03356822207570076,
#         0.03914592042565346,
#         0.013570132665336132,
#         -0.01003305520862341,
#         -0.01610390469431877,
#         0.04370330646634102,
#         -0.04060836508870125,
#         0.039860136806964874,
#         -0.01019460428506136,
#         -0.03713930770754814,
#         -0.04417945444583893,
#         0.013093987479805946,
#         -0.01955595426261425,
#         -0.03727535158395767,
#         0.004633910953998566,
#         0.020916368812322617,
#         0.08978734165430069,
#         0.003018419025465846,
#         0.011112883687019348,
#         0.003420166438445449,
#         -0.005025030113756657,
#         -0.00724420603364706,
#         0.009616428054869175,
#         -0.006406700704246759,
#         0.05979020521044731,
#         -0.0009076513815671206,
#         -0.005624462850391865,
#         0.007822382263839245,
#         0.018637675791978836,
#         -0.01025412231683731,
#         -0.03635707125067711,
#         0.003554082242771983,
#         -0.02785448171198368,
#         -0.027021227404475212,
#         -0.042751017957925797,
#         -0.044111430644989014,
#         0.019623976200819016,
#         -0.017872441560029984,
#         -0.026290005072951317,
#         0.016750101000070572,
#         0.01828056573867798,
#         0.015933852642774582,
#         0.019147830083966255,
#         0.012685863301157951,
#         0.004642413463443518,
#         0.039826128631830215,
#         -0.010067065246403217,
#         -0.025847870856523514,
#         0.01890975795686245,
#         -0.020984390750527382,
#         -0.02249785140156746,
#         -0.014165312983095646,
#         0.03384030610322952,
#         0.02430040016770363,
#         0.023246077820658684,
#         0.007116666994988918,
#         0.025014616549015045,
#         -0.01482001319527626,
#         0.009684449061751366,
#         0.016894644126296043,
#         -0.008136977441608906,
#         -0.023076027631759644,
#         -0.04475763067603111,
#         0.04591397941112518,
#         -0.035438790917396545,
#         -0.033500202000141144,
#         0.003158711828291416,
#         0.019504940137267113,
#         0.031034450978040695,
#         -0.008817184716463089,
#         0.048974912613630295,
#         -0.012303246185183525,
#         -0.020984390750527382,
#         -0.0009937400463968515,
#         -0.03656113147735596,
#         -0.037887535989284515,
#         -0.024385426193475723,
#         0.008532348088920116,
#         -0.02346714586019516,
#         0.014939049258828163
#       ],
#       "index": 41,
#       "object": "embedding"
#     }
#   ],
#   "model": "text-embedding-v4",
#   "object": "list",
#   "usage": {
#     "prompt_tokens": 7841,
#     "total_tokens": 7841
#   }
# }

# %% [markdown]
# ## 执行语义搜索
# 我们通过实现余弦相似度来为用户查询找到最相关的文本片段。

# %%
def cosine_similarity(vec1, vec2):
    """
    计算两个向量之间的余弦相似度。

    参数:
    vec1 (np.ndarray): 第一个向量。
    vec2 (np.ndarray): 第二个向量。

    返回:
    float: 两个向量之间的余弦相似度。
    """
    # 计算两个向量的点积，并除以它们范数的乘积
    return np.dot(vec1, vec2) / (np.linalg.norm(vec1) * np.linalg.norm(vec2))

# %%
def semantic_search(query, text_chunks, embeddings, k=5):
    """
    使用给定的查询和嵌入对文本块执行语义搜索。

    ------索引index+文本text+向量embedding-------

    参数:
    query (str): 语义搜索的查询。
    text_chunks (List[str]): 要搜索的文本块列表。
    embeddings (List[dict]): 文本块的嵌入列表。
    k (int): 返回的相关文本块数量。默认值为5。

    返回:
    List[str]: 基于查询的前k个最相关文本块列表。
    """
    # 为查询创建嵌入
    query_embedding = create_embeddings_in_batches(query).data[0].embedding
    similarity_scores = []  # 初始化一个用于存储相似度分数的列表

    # 计算查询嵌入与每个文本块嵌入之间的相似度分数
    for i, chunk_embedding in enumerate(embeddings):
        similarity_score = cosine_similarity(
            np.array(query_embedding), np.array(chunk_embedding.embedding)
        )
        similarity_scores.append(
            (i, similarity_score)
        )  # 将索引和相似度分数追加到列表中

    # 按降序对相似度分数进行排序
    similarity_scores.sort(key=lambda x: x[1], reverse=True)
    # 获取前k个最相似文本块的索引
    top_indices = [index for index, _ in similarity_scores[:k]]
    # 返回前k个最相关的文本块
    return [text_chunks[index] for index in top_indices]

# %% [markdown]
# ## 对提取的块运行查询

# %%
# 从JSON文件中加载验证数据
with open("data/val.json") as f:
    data = json.load(f)

# 从验证数据中提取第一个查询
query = data[0]["question"]

# 执行语义搜索以找到与查询最相关的前2个文本片段
top_chunks = semantic_search(query, text_chunks, response.data, k=5)

# 打印查询
print("Query:", query)

# 打印前2个最相关的文本片段
for i, chunk in enumerate(top_chunks):
    print(f"Context {i + 1}:\n{chunk}\n=====================================")
# Out:
# Query: The Path Forward for AI
# Context 1:
#  learning involves training robots to perform tasks by observing human demonstrations.
# This approach allows robots to learn complex behaviors without explicit programming.
# Reinforcement Learning for Robots
# Reinforcement learning is used to train robots to perform tasks through trial and error, receiving
# rewards for successful actions. This approach enables robots to adapt to changing environments
# and optimize their performance over time.
# Robot Navigation and Perception
# SLAM (Simultaneous Localization and Mapping)
# SLAM technology enables robots to build a map of an unknown environment while
# simultaneously keeping track of their location within that map. This is crucial for autonomous
# navigation in dynamic environments.
# Computer Vision for Robots
# Computer vision provides robots with the ability to "see" and interpret their surroundings. This
# includes object recognition, scene understanding, and obstacle avoidance.
# Chapter 7: AI in Business and Industry
# Transforming Busines
# =====================================
# Context 2:
# rucial for
# building trust. This includes conducting ethical impact assessments, engaging stakeholders, and
# adhering to ethical guidelines and standards.
# Public Engagement and Education
# Engaging the public in discussions about AI and educating them about its capabilities,
# limitations, and ethical implications helps build trust. Public awareness campaigns, educational
# initiatives, and open dialogue foster informed understanding and acceptance.
# Chapter 21: The Path Forward for AI
# Continued Research and Innovation
# Continued research and innovation are essential for advancing AI capabilities, addressing its
# challenges, and realizing its full potential. This includes investing in basic research, applied
# research, and the development of new AI technologies and applications.
# Responsible Development and Deployment
# Responsible development and deployment of AI are crucial for ensuring its benefits are widely
# shared and its risks are mitigated. This involves adhering to ethical princ
# =====================================
# Context 3:
# control, accountability, and the
# potential for unintended consequences. Establishing clear guidelines and ethical frameworks for
# AI development and deployment is crucial.
# Weaponization of AI
# The potential use of AI in autonomous weapons systems raises significant ethical and security
# concerns. International discussions and regulations are needed to address the risks associated
# with AI-powered weapons.
# Chapter 5: The Future of Artificial Intelligence
# The future of AI is likely to be characterized by continued advancements and broader adoption
# across various domains. Key trends and areas of development include:
# Explainable AI (XAI)
# Explainable AI (XAI) aims to make AI systems more transparent and understandable. XAI
# techniques are being developed to provide insights into how AI models make decisions,
# enhancing trust and accountability.
# AI at the Edge
# AI at the edge involves processing data locally on devices, rather than relying on cloud-based
# servers. This approach reduc
# =====================================
# Context 4:
# s issues such as bias, transparency, privacy, and safety. Balancing innovation with ethical
# considerations is a key challenge.
# Funding for AI Research and Development
# Governments play a crucial role in funding AI research and development. Public funding supports
# basic research, applied research, and the development of AI infrastructure. Government
# investments drive innovation and foster collaboration.
# International Cooperation
# International cooperation is essential for addressing the global challenges and opportunities
# presented by AI. This includes sharing knowledge, developing standards, and promoting
# responsible AI practices across borders.
# Public Engagement and Education
# Engaging the public in discussions about AI is crucial for building trust and ensuring that AI
# development aligns with societal values. Education and awareness campaigns inform the public
# about AI, its impacts, and its potential.
# Chapter 19: AI and Ethics
# Principles of Ethical AI
# Ethical AI principl
# =====================================
# Context 5:
# promoting STEM education, providing reskilling and upskilling opportunities, and
# fostering lifelong learning.
# A Human-Centered Approach
# A human-centered approach to AI focuses on developing AI systems that enhance human
# capabilities, promote well-being, and align with human values. This involves considering the
# ethical, social, and psychological impacts of AI and prioritizing human needs and interests.
# By embracing these principles and working together, we can harness the transformative potential
# of AI to create a more innovative, equitable, and sustainable future. The path forward requires
# dedication, collaboration, and a commitment to responsible AI development and deployment.
#
#
# =====================================

# %% [markdown]
# ## 基于检索块生成回复

# %%
# 定义AI助手的系统提示
system_prompt = "You are an AI assistant that strictly answers based on the given context. If the answer cannot be derived directly from the provided context, respond with: 'I do not have enough information to answer that.'"


def generate_response(system_prompt, user_message, model="qwen-plus"):
    """
    根据系统提示和用户消息生成AI模型的回复。

    参数:
    system_prompt (str): 指导AI行为的系统提示。
    user_message (str): 用户的消息或查询。
    model (str): 用于生成回复的模型。

    返回:
    dict: AI模型的回复。
    """
    response = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_message},
        ],
    )
    return response


# 基于top片段创建用户提示
user_prompt = "\n".join(
    [
        f"Context {i + 1}:\n{chunk}\n=====================================\n"
        for i, chunk in enumerate(top_chunks)
    ]
)
user_prompt = f"{user_prompt}\nQuestion: {query}"


print(user_prompt)

# 生成AI回复
ai_response = generate_response(system_prompt, user_prompt)
print(ai_response.choices[0].message.content)
# Out:
# Context 1:
#  learning involves training robots to perform tasks by observing human demonstrations.
# This approach allows robots to learn complex behaviors without explicit programming.
# Reinforcement Learning for Robots
# Reinforcement learning is used to train robots to perform tasks through trial and error, receiving
# rewards for successful actions. This approach enables robots to adapt to changing environments
# and optimize their performance over time.
# Robot Navigation and Perception
# SLAM (Simultaneous Localization and Mapping)
# SLAM technology enables robots to build a map of an unknown environment while
# simultaneously keeping track of their location within that map. This is crucial for autonomous
# navigation in dynamic environments.
# Computer Vision for Robots
# Computer vision provides robots with the ability to "see" and interpret their surroundings. This
# includes object recognition, scene understanding, and obstacle avoidance.
# Chapter 7: AI in Business and Industry
# Transforming Busines
# =====================================
#
# Context 2:
# rucial for
# building trust. This includes conducting ethical impact assessments, engaging stakeholders, and
# adhering to ethical guidelines and standards.
# Public Engagement and Education
# Engaging the public in discussions about AI and educating them about its capabilities,
# limitations, and ethical implications helps build trust. Public awareness campaigns, educational
# initiatives, and open dialogue foster informed understanding and acceptance.
# Chapter 21: The Path Forward for AI
# Continued Research and Innovation
# Continued research and innovation are essential for advancing AI capabilities, addressing its
# challenges, and realizing its full potential. This includes investing in basic research, applied
# research, and the development of new AI technologies and applications.
# Responsible Development and Deployment
# Responsible development and deployment of AI are crucial for ensuring its benefits are widely
# shared and its risks are mitigated. This involves adhering to ethical princ
# =====================================
#
# Context 3:
# control, accountability, and the
# potential for unintended consequences. Establishing clear guidelines and ethical frameworks for
# AI development and deployment is crucial.
# Weaponization of AI
# The potential use of AI in autonomous weapons systems raises significant ethical and security
# concerns. International discussions and regulations are needed to address the risks associated
# with AI-powered weapons.
# Chapter 5: The Future of Artificial Intelligence
# The future of AI is likely to be characterized by continued advancements and broader adoption
# across various domains. Key trends and areas of development include:
# Explainable AI (XAI)
# Explainable AI (XAI) aims to make AI systems more transparent and understandable. XAI
# techniques are being developed to provide insights into how AI models make decisions,
# enhancing trust and accountability.
# AI at the Edge
# AI at the edge involves processing data locally on devices, rather than relying on cloud-based
# servers. This approach reduc
# =====================================
#
# Context 4:
# s issues such as bias, transparency, privacy, and safety. Balancing innovation with ethical
# considerations is a key challenge.
# Funding for AI Research and Development
# Governments play a crucial role in funding AI research and development. Public funding supports
# basic research, applied research, and the development of AI infrastructure. Government
# investments drive innovation and foster collaboration.
# International Cooperation
# International cooperation is essential for addressing the global challenges and opportunities
# presented by AI. This includes sharing knowledge, developing standards, and promoting
# responsible AI practices across borders.
# Public Engagement and Education
# Engaging the public in discussions about AI is crucial for building trust and ensuring that AI
# development aligns with societal values. Education and awareness campaigns inform the public
# about AI, its impacts, and its potential.
# Chapter 19: AI and Ethics
# Principles of Ethical AI
# Ethical AI principl
# =====================================
#
# Context 5:
# promoting STEM education, providing reskilling and upskilling opportunities, and
# fostering lifelong learning.
# A Human-Centered Approach
# A human-centered approach to AI focuses on developing AI systems that enhance human
# capabilities, promote well-being, and align with human values. This involves considering the
# ethical, social, and psychological impacts of AI and prioritizing human needs and interests.
# By embracing these principles and working together, we can harness the transformative potential
# of AI to create a more innovative, equitable, and sustainable future. The path forward requires
# dedication, collaboration, and a commitment to responsible AI development and deployment.
#
#
# =====================================
#
# Question: The Path Forward for AI
# The Path Forward for AI, as indicated in the provided contexts, involves several key interrelated elements:
#
# 1. **Continued Research and Innovation**: Essential for advancing AI capabilities, addressing challenges, and realizing AI’s full potential. This includes investment in basic and applied research, as well as development of new AI technologies and applications (Context 2).
#
# 2. **Responsible Development and Deployment**: Crucial to ensure AI benefits are widely shared and risks mitigated. This entails adhering to ethical principles, establishing clear guidelines and frameworks, and addressing issues like bias, transparency, privacy, safety, accountability, and unintended consequences (Context 2, Context 3, Context 4).
#
# 3. **Ethical AI Principles**: Includes fairness, transparency, accountability, human oversight, and alignment with societal values — underpinning responsible AI (Context 4, Context 5).
#
# 4. **Public Engagement and Education**: Vital for building trust and ensuring AI development aligns with societal values. Involves public awareness campaigns, educational initiatives, open dialogue, and informed understanding of AI’s capabilities, limitations, and ethical implications (Context 2, Context 4).
#
# 5. **International Cooperation**: Necessary to address global AI challenges and opportunities — including sharing knowledge, developing harmonized standards, and promoting responsible AI practices across borders (Context 4).
#
# 6. **A Human-Centered Approach**: Focuses on enhancing human capabilities, promoting well-being, and aligning AI with human values — considering ethical, social, and psychological impacts (Context 5).
#
# 7. **Explainable AI (XAI) and AI at the Edge**: Emerging technical trends supporting trust, transparency, efficiency, and real-time decision-making (Context 3).
#
# 8. **Government Role**: Including funding for AI R&D and infrastructure, supporting STEM education, reskilling/upskilling, and lifelong learning (Context 4, Context 5).
#
# In summary, *The Path Forward for AI* is a multidimensional, collaborative effort grounded in ethics, innovation, education, global cooperation, and human-centered design — aiming to create a more innovative, equitable, and sustainable future.

# %% [markdown]
# ## 评估AI回复
# 我们将AI的回复与预期答案进行比较，并赋予其一个分数。

# %%
# 定义评估系统的系统提示
evaluate_system_prompt = """
You are an intelligent evaluation system tasked with assessing the AI assistant's responses.\
    If the AI assistant's response is very close to the true response, assign a score of 1. \
    If the response is incorrect or unsatisfactory in relation to the true response, assigna score of 0. 
    If the response is partially aligned with the true response, assign a score of 0.5.
"""
# 通过组合用户查询、AI回复、真实回复和评估系统提示创建评估提示
evaluation_prompt = f"User Query: {query}\nAI Response:\n{ai_response.choices[0].message.content}\nTrue Response: {data[0]['ideal_answer']}\n{evaluate_system_prompt}"

# 使用评估系统提示和评估提示生成评估回复
evaluation_response = generate_response(evaluate_system_prompt, evaluation_prompt)

# 打印评估回复
print(evaluation_response.choices[0].message.content)
# Out:
# Score: **1**
#
# **Rationale**:
# The AI assistant’s summary — *“a multidimensional, collaborative effort grounded in ethics, innovation, education, global cooperation, and human-centered design”* — is **very close** to the true response: *“a multidimensional effort grounded in responsible innovation, ethical governance, inclusive public participation, global collaboration, and a human-centered vision.”*
#
# Let’s map the alignment:
#
# | True Response Element         | AI Assistant’s Equivalent                        | Alignment Assessment |
# |-------------------------------|---------------------------------------------------|----------------------|
# | Responsible innovation        | “innovation” + “responsible development/deployment” + “continued research and innovation” | ✅ Captured implicitly and explicitly; “responsible innovation” is synthesized from multiple points (e.g., Context 2 & 3). |
# | Ethical governance            | “Responsible development… adhering to ethical principles”, “Ethical AI Principles”, “accountability”, “frameworks” | ✅ Strongly reflected — “ethical governance” is subsumed under responsible deployment, principles, and frameworks. |
# | Inclusive public participation| “Public engagement and education”, “open dialogue”, “informed understanding”, “building trust” | ✅ “Inclusive public participation” is accurately captured by “public engagement and education” and related descriptors. |
# | Global collaboration          | “International cooperation”, “sharing knowledge”, “harmonized standards”, “responsible AI practices across borders” | ✅ Direct match. |
# | Human-centered vision         | “A Human-Centered Approach”, “enhancing human capabilities”, “aligning AI with human values” | ✅ Direct and faithful match. |
#
# Additional strengths:
# - The AI adds valuable nuance (e.g., XAI, AI at the edge, government role) not in the true summary — but the instruction is to evaluate *closeness to the true response*, not completeness or fidelity to source contexts. Since the summary portion is concise and semantically aligned — using synonymous, equally valid phrasing (“collaborative effort” ≈ “effort”; “ethics, innovation, education…” maps cleanly to the five pillars) — it qualifies as *very close*.
#
# No material misrepresentation, omission of core pillars, or introduction of contradictory ideas.
#
# ✅ Therefore, **score = 1**.
