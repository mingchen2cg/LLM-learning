# %% [markdown]
# # 增强RAG系统的查询转换
#
# 本笔记本实现了三种查询转换技术，以在不依赖LangChain等专用库的情况下提升RAG系统中的检索性能。通过修改用户查询，可以显著提高检索到的信息的相关性和全面性。
#
# ## 关键转换技术
#
# 1. **查询重写**：使查询更加具体和详细，从而提高搜索的精确度。
# 2. **后退提示生成**：生成更广泛的查询以检索有用的上下文信息。
# 3. **子查询分解**：将复杂的查询分解为更简单的组件，以实现全面检索。

# %% [markdown]
# ![image.png](attachment:e45e838f-4e28-4410-b52c-78d1bbca87e5.png)

# %% [markdown]
# ## 环境设置
# 首先，我们导入必要的库。

# %%
import fitz  # PyMuPDF，用于处理 PDF 文件
import os  # 操作系统相关功能，如文件路径处理
import numpy as np  # NumPy，用于数值计算
import json  # JSON 数据处理
from openai import OpenAI  # OpenAI API 客户端库

# %% [markdown]
# ## 设置OpenAI API客户端
# 我们初始化OpenAI客户端以生成嵌入向量和回复。

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # 加载.env文件
api_key = os.getenv("DASHSCOPE_API_KEY")  # 读取密钥
base_url = os.getenv("base_url")

# 初始化 OpenAI 客户端，设置基础 URL 和 API 密钥
client = OpenAI(base_url=base_url, api_key=api_key)

# %% [markdown]
# ## 实现查询转换技术
# ### 1. 查询重写
# 该技术通过使查询更加具体和详细来提高检索的精确性。

# %%
def rewrite_query(original_query, model="qwen-plus"):
    """
    根据给定的原始查询重新编写查询，使其更加具体和详细，以便更好地检索信息。
    
    参数:
        original_query (str): 原始用户查询
        model (str): 用于查询重写的模型名称
        
    返回:
        str: 重写后的查询
    """
    # 中文系统提示，指导AI助手的行为
    system_prompt = "你是一名擅长优化检索查询的AI助手。你的任务是将用户的查询改写得更加具体、详细，并包含有助于检索准确信息的相关术语和概念。"

    # 中文用户提示，包含需要被重写的原始查询
    user_prompt = f"""
请将下列查询改写为更具体、更详细的表达，补充相关的关键词和概念，以便更好地检索到准确的信息。

原始查询：{original_query}

改写后的查询：
"""

    # 使用指定的模型生成重写后的查询
    response = client.chat.completions.create(
        model=model,
        temperature=0.0,  # 低温度值以确保输出确定性
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    
    # 返回重写后的查询，并去除任何前导或尾随空白字符
    return response.choices[0].message.content.strip()

# %% [markdown]
# ### 2. 后退提示（Step-back Prompting）
# 该技术生成更广泛的查询，以检索上下文背景信息。

# %%
def generate_step_back_query(original_query, model="qwen-plus"):
    """
    生成一个更通用的“后退一步”查询，以检索更广泛的上下文。
    
    参数:
        original_query (str): 原始用户查询
        model (str): 用于生成后退一步查询的模型
        
    返回:
        str: 后退一步查询
    """
    # 中文系统提示，指导AI助手的行为
    system_prompt = "你是一名擅长检索策略的AI助手。你的任务是将具体的用户查询改写为更宽泛、更通用的问题，以便检索到相关的背景信息和更广泛的上下文。"

    # 中文用户提示，包含需要被泛化的原始查询
    user_prompt = f"""
请将下列查询改写为更宽泛、更通用的问题，以便有助于检索相关的背景信息和更广泛的上下文。

原始查询：{original_query}

后退一步的查询：
"""

    # 使用指定的模型生成后退一步查询
    response = client.chat.completions.create(
        model=model,
        temperature=0.1,  # 稍高的温度以获得一些变化
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    
    # 返回后退一步查询，并去除任何前导/尾随空白字符
    return response.choices[0].message.content.strip()

# %% [markdown]
# ### 3. 子查询分解
# 该技术将复杂的查询拆解为更简单的组件，以实现全面检索。

# %%
def decompose_query(original_query, num_subqueries=4, model="qwen-plus"):
    """
    将复杂的查询分解为更简单的子查询。
    
    参数:
        original_query (str): 原始的复杂查询
        num_subqueries (int): 生成的子查询数量
        model (str): 用于查询分解的模型
        
    返回:
        List[str]: 一个包含简单子查询的列表
    """
    # 中文系统提示，指导AI助手的行为
    system_prompt = "你是一名擅长将复杂问题拆解为简单子问题的AI助手。你的任务是把复杂的用户查询分解为若干个更简单、聚焦不同方面的子问题，所有子问题的答案合起来可以完整回答原始问题。"

    # 中文用户提示，包含待分解的原始查询
    user_prompt = f"""
请将下列复杂查询拆解为 {num_subqueries} 个更简单的子问题。每个子问题应关注原始问题的不同方面。

原始查询：{original_query}

请生成 {num_subqueries} 个子问题，每行一个，格式如下：
1. [第一个子问题]
2. [第二个子问题]
以此类推……
"""

    # 使用指定的模型生成子查询
    response = client.chat.completions.create(
        model=model,
        temperature=0.2,  # 稍高的温度以获得一些变化
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    
    # 处理回复以提取子查询
    content = response.choices[0].message.content.strip()
    
    # 使用简单的解析方法提取编号的查询
    lines = content.split("\n")
    sub_queries = []
    
    for line in lines:
        if line.strip() and any(line.strip().startswith(f"{i}.") for i in range(1, 10)):
            # 移除编号和前导空格
            query = line.strip()
            query = query[query.find(".")+1:].strip()
            sub_queries.append(query)
    
    return sub_queries

# %% [markdown]
# ## 展示查询转换技术
# 让我们将这些技术应用到一个示例查询中。

# %%
# 示例查询
original_query = "中国政府在AI上有哪些政策?"

# 应用查询变换
print("Original Query:", original_query)

# 查询重写
rewritten_query = rewrite_query(original_query)
print("\n1. Rewritten Query:")
print(rewritten_query)

# 后退提示生成
step_back_query = generate_step_back_query(original_query)
print("\n2. Step-back Query:")
print(step_back_query)

# 子查询分解
sub_queries = decompose_query(original_query, num_subqueries=4)
print("\n3. Sub-queries:")
for i, query in enumerate(sub_queries, 1):
    print(f"   {i}. {query}")
# Out:
# Original Query: 中国政府在AI上有哪些政策?
#
# 1. Rewritten Query:
# 改写后的查询：
# “中国政府近年来（2020–2024年）在人工智能领域出台的国家级战略规划、法律法规、行业监管政策及支持措施有哪些？请重点涵盖《新一代人工智能发展规划》（2017年发布，后续修订与落实情况）、《生成式人工智能服务管理暂行办法》（2023年施行）、《人工智能算法推荐管理规定》《互联网信息服务深度合成管理规定》，以及数据安全（如《数据安全法》《个人信息保护法》对AI应用的约束）、算力基础设施（‘东数西算’工程与智算中心建设）、AI伦理治理（国家人工智能治理专委会、《人工智能伦理规范》）、产业扶持政策（专精特新企业支持、AI大模型研发专项、信创适配要求）等维度，并说明主管部门（如科技部、网信办、工信部、发改委）的职责分工与协同机制。”
#
# 该改写强化了：
# ✅ 时间范围（突出近年关键节点）
# ✅ 政策层级（国家战略→部门规章→技术标准）
# ✅ 核心文件名称（含发布时间与效力状态）
# ✅ 关键交叉领域（数据治理、算力底座、伦理框架、产业落地）
# ✅ 主管机构及其职能定位
# ✅ 检索友好性（包含中英文常用术语，如“generative AI”“AI governance”“algorithmic accountability”，便于中英文数据库联合检索）
#
# 如需进一步聚焦某一方面（如“大模型监管”“AI医疗审批路径”或“地方配套政策如上海/深圳AI条例”），可继续细化。
#
# 2. Step-back Query:
# 后退一步的查询：
# 全球各国政府在人工智能领域采取了哪些主要治理框架、战略规划与政策方向？
#
# 3. Sub-queries:
#    1. 中国政府在人工智能领域发布了哪些国家级战略规划或顶层设计文件？
#    2. 针对AI研发、应用与治理，中国出台了哪些具体的法律法规或部门规章？
#    3. 在AI产业发展和技术创新方面，中国政府提供了哪些财政支持、试点项目或基础设施建设政策？
#    4. 中国在人工智能伦理、数据安全、算法监管及国际治理合作方面提出了哪些政策主张或行动框架？

# %% [markdown]
# ## 构建一个简单的向量存储
# 为了展示查询转换如何与检索集成，让我们实现一个简单的向量存储。

# %%
class SimpleVectorStore:
    """
    一个使用NumPy实现的简单向量存储。
    """
    def __init__(self):
        """
        初始化向量存储。
        """
        self.vectors = []  # 存储嵌入向量的列表
        self.texts = []  # 存储原始文本的列表
        self.metadata = []  # 存储每个文本元数据的列表
    
    def add_item(self, text, embedding, metadata=None):
        """
        向向量存储中添加一项。

        参数:
        text (str): 原始文本。
        embedding (List[float]): 嵌入向量。
        metadata (dict, 可选): 额外的元数据。
        """
        self.vectors.append(np.array(embedding))  # 将嵌入转换为numpy数组并添加到向量列表中
        self.texts.append(text)  # 将原始文本添加到文本列表中
        self.metadata.append(metadata or {})  # 添加元数据到元数据列表，如果为None则使用空字典
    
    def similarity_search(self, query_embedding, k=5):
        """
        查找与查询嵌入最相似的项。

        参数:
        query_embedding (List[float]): 查询嵌入向量。
        k (int): 返回结果的数量。

        返回:
        List[Dict]: 最相似的k个项及其文本和元数据。
        """
        if not self.vectors:
            return []  # 如果没有存储向量，则返回空列表
        
        # 将查询嵌入转换为numpy数组
        query_vector = np.array(query_embedding)
        
        # 使用余弦相似度计算相似性
        similarities = []
        for i, vector in enumerate(self.vectors):
            # 计算查询向量和存储向量之间的余弦相似度
            similarity = np.dot(query_vector, vector) / (np.linalg.norm(query_vector) * np.linalg.norm(vector))
            similarities.append((i, similarity))  # 将索引和相似度分数添加到列表中
        
        # 按相似度降序排序
        similarities.sort(key=lambda x: x[1], reverse=True)
        
        # 返回前k个结果
        results = []
        for i in range(min(k, len(similarities))):
            idx, score = similarities[i]
            results.append({
                "text": self.texts[idx],  # 添加对应的文本
                "metadata": self.metadata[idx],  # 添加对应的元数据
                "similarity": score  # 添加相似度分数
            })
        
        return results  # 返回前k个相似项的列表

# %% [markdown]
# ## 创建嵌入（Embeddings）

# %%
def create_embeddings(text, model="text-embedding-v4"):
    """
    使用指定的模型为给定文本创建嵌入。

    参数:
    text (str): 需要创建嵌入的输入文本。
    model (str): 用于创建嵌入的模型。

    返回:
    List[float]: 嵌入向量。
    """
    # 1. 统一转换为列表进行批处理计算
    input_text = [text] if isinstance(text, str) else text

    max_batch_size = 10
    all_embeddings = []

    # 2. 按照每 10 个一组进行分批请求，避免触发 API 限制
    for i in range(0, len(input_text), max_batch_size):
        batch = input_text[i : i + max_batch_size]
        response = client.embeddings.create(model=model, input=batch)
        # 将当前批次的结果提取并合并
        all_embeddings.extend([item.embedding for item in response.data])

    # 3. 严格遵循原有的返回逻辑：
    # 如果输入是字符串，则返回第一个嵌入向量 (List[float])
    if isinstance(text, str):
        return all_embeddings[0]

    # 否则，返回所有嵌入向量的列表 (List[List[float]])
    return all_embeddings

# %% [markdown]
# ## 使用查询转换实现RAG

# %%
def extract_text_from_pdf(pdf_path):
    """
    从PDF文件中提取文本。

    参数:
    pdf_path (str): PDF文件的路径。

    返回:
    str: 从PDF中提取的文本。
    """
    # 打开PDF文件
    mypdf = fitz.open(pdf_path)
    all_text = ""  # 初始化一个空字符串用于存储提取的文本

    # 遍历PDF中的每一页
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]  # 获取页面
        text = page.get_text("text")  # 从页面提取文本
        all_text += text  # 将提取的文本追加到all_text字符串中

    return all_text  # 返回提取的文本

# %%
def chunk_text(text, n=1000, overlap=200):
    """
    将给定的文本分割为每段包含 n 个字符且具有重叠部分的片段。

    参数:
    text (str): 需要分割的文本。
    n (int): 每个片段包含的字符数量。
    overlap (int): 相邻片段之间的重叠字符数量。

    返回:
    List[str]: 一个包含文本片段的列表。
    """
    chunks = []  # 初始化一个空列表用于存储片段
    
    # 使用 (n - overlap) 的步长遍历文本
    for i in range(0, len(text), n - overlap):
        # 将从索引 i 到 i + n 的文本片段添加到 chunks 列表中
        chunks.append(text[i:i + n])

    return chunks  # 返回包含文本片段的列表

# %%
def process_document(pdf_path, chunk_size=1000, chunk_overlap=200):
    """
    处理文档以供RAG使用。

    参数:
    pdf_path (str): PDF文件的路径。
    chunk_size (int): 每个块的字符数大小。
    chunk_overlap (int): 块之间的重叠字符数。

    返回:
    SimpleVectorStore: 包含文档块及其嵌入的向量存储。
    """
    print("Extracting text from PDF...")
    extracted_text = extract_text_from_pdf(pdf_path)
    
    print("Chunking text...")
    chunks = chunk_text(extracted_text, chunk_size, chunk_overlap)
    print(f"Created {len(chunks)} text chunks")
    
    print("Creating embeddings for chunks...")
    # 为了提高效率，一次性为所有块创建嵌入
    chunk_embeddings = create_embeddings(chunks)
    
    # 创建向量存储
    store = SimpleVectorStore()
    
    # 将块添加到向量存储中
    for i, (chunk, embedding) in enumerate(zip(chunks, chunk_embeddings)):
        store.add_item(
            text=chunk,
            embedding=embedding,
            metadata={"index": i, "source": pdf_path}
        )
    
    print(f"Added {len(chunks)} chunks to the vector store")
    return store

# %% [markdown]
# ## 带查询转换的RAG

# %%
def transformed_search(query, vector_store, transformation_type, top_k=3):
    """
    使用转换后的查询进行搜索。

    参数:
        query (str): 原始查询
        vector_store (SimpleVectorStore): 要搜索的向量存储
        transformation_type (str): 转换类型 ('rewrite', 'step_back' 或 'decompose')
        top_k (int): 返回的结果数量

    返回:
        List[Dict]: 搜索结果
    """
    print(f"Transformation type: {transformation_type}")
    print(f"Original query: {query}")
    
    results = []
    
    if transformation_type == "rewrite":
        # 查询重写
        transformed_query = rewrite_query(query)
        print(f"Rewritten query: {transformed_query}")
        
        # 为转换后的查询创建嵌入
        query_embedding = create_embeddings(transformed_query)
        
        # 使用重写后的查询进行搜索
        results = vector_store.similarity_search(query_embedding, k=top_k)
        
    elif transformation_type == "step_back":
        # 向后提示
        transformed_query = generate_step_back_query(query)
        print(f"Step-back query: {transformed_query}")
        
        # 为转换后的查询创建嵌入
        query_embedding = create_embeddings(transformed_query)
        
        # 使用向后查询进行搜索
        results = vector_store.similarity_search(query_embedding, k=top_k)
        
    elif transformation_type == "decompose":
        # 子查询分解
        sub_queries = decompose_query(query)
        print("Decomposed into sub-queries:")
        for i, sub_q in enumerate(sub_queries, 1):
            print(f"{i}. {sub_q}")
        
        # 为所有子查询创建嵌入
        sub_query_embeddings = create_embeddings(sub_queries)
        
        # 对每个子查询进行搜索并组合结果
        all_results = []
        for i, embedding in enumerate(sub_query_embeddings):
            sub_results = vector_store.similarity_search(embedding, k=2)  # 每个子查询获取较少的结果
            all_results.extend(sub_results)
        
        # 去重（保留最高的相似度分数）
        seen_texts = {}
        for result in all_results:
            text = result["text"]
            if text not in seen_texts or result["similarity"] > seen_texts[text]["similarity"]:
                seen_texts[text] = result
        
        # 按相似度排序并取前 top_k 个结果
        results = sorted(seen_texts.values(), key=lambda x: x["similarity"], reverse=True)[:top_k]
        
    else:
        # 无转换的常规搜索
        query_embedding = create_embeddings(query)
        results = vector_store.similarity_search(query_embedding, k=top_k)
    
    return results

# %% [markdown]
# ## 基于转换查询生成回复

# %%
def generate_response(query, context, model="qwen-plus"):
    """
    根据查询和检索到的上下文生成回复。
    
    参数:
        query (str): 用户查询
        context (str): 检索到的上下文
        model (str): 用于回复生成的模型
    
    返回:
        str: 生成的回复
    """
    # 定义系统提示以指导AI助手的行为
    system_prompt = (
        "你是一名乐于助人的AI助手，只能根据提供的上下文内容回答用户的问题。"
        "如果在上下文中找不到答案，请明确说明“我没有足够的信息来回答该问题”。"
    )
    # 定义包含上下文和查询的用户提示
    user_prompt = f"""
        Context:
        {context}

        Question: {query}

        基于上面的内容提供一个综合性的回答.
    """
    
    # 使用指定的模型生成回复
    response = client.chat.completions.create(
        model=model,
        temperature=0,  # 低温度以确保确定性输出
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    
    # 返回生成的回复，并去除任何前导/尾随空白字符
    return response.choices[0].message.content.strip()

# %% [markdown]
# ## 运行包含查询转换的完整RAG管道

# %%
def rag_with_query_transformation(pdf_path, query, transformation_type=None):
    """
    运行完整的RAG管道并支持可选的查询转换。
    
    参数:
        pdf_path (str): PDF文档的路径
        query (str): 用户查询
        transformation_type (str): 转换类型（None、'rewrite'、'step_back' 或 'decompose'）
        
    返回:
        Dict: 包括原始查询、转换类型、上下文和回复的结果字典
    """
    # 处理文档以创建向量存储
    vector_store = process_document(pdf_path)
    
    # 应用查询转换并执行搜索
    if transformation_type:
        # 使用转换后的查询执行搜索
        results = transformed_search(query, vector_store, transformation_type)
    else:
        # 在不进行转换的情况下执行常规搜索
        query_embedding = create_embeddings(query)
        results = vector_store.similarity_search(query_embedding, k=3)
    
    # 组合搜索结果的上下文
    context = "\n\n".join([f"PASSAGE {i+1}:\n{result['text']}" for i, result in enumerate(results)])
    
    # 基于查询和组合的上下文生成回复
    response = generate_response(query, context)
    
    # 返回包括原始查询、转换类型、上下文和回复的结果字典
    return {
        "original_query": query,
        "transformation_type": transformation_type,
        "context": context,
        "response": response
    }

# %% [markdown]
# ## 评估变换技术

# %%
def compare_responses(results, reference_answer, model="qwen-plus"):
    """
    比较来自不同查询转换技术的回复。
    
    参数:
        results (Dict): 来自不同转换技术的结果
        reference_answer (str): 用于比较的参考答案
        model (str): 用于评估的模型
    """
    # 中文系统提示
    system_prompt = (
        "你是一名RAG系统的专家评测员。"
        "你的任务是比较使用不同查询转换技术生成的回复，"
        "并判断哪种技术生成的回复与参考答案最为接近。"
    )
    
    # 准备包含参考答案和每种技术回复的比较文本
    comparison_text = f"参考答案：{reference_answer}\n\n"
    for technique, result in results.items():
        comparison_text += f"{technique.capitalize()} 查询回复：\n{result['response']}\n\n"
    
    # 中文用户提示
    user_prompt = f"""
{comparison_text}

请将不同查询转换技术（original, rewrite, step_back, decompose）生成的回复与参考答案进行比较。

对于每种技术，请：
1. 从准确性、完整性和相关性三个方面，对该技术的回复进行1-10分的评分；
2. 分析每种技术的优点和不足。

最后，请对所有技术进行从优到劣的排序，并说明哪种技术整体表现最好以及原因。
"""

    # 使用指定模型生成评估回复
    response = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    
    # 打印评估结果
    print("\n===== 评测结果 =====")
    print(response.choices[0].message.content)
    print("===================")

# %%
def evaluate_transformations(pdf_path, query, reference_answer=None):
    """
    评估相同查询的不同转换技术。

    参数:
        pdf_path (str): PDF 文档的路径
        query (str): 要评估的查询
        reference_answer (str): 可选的参考答案用于比较

    返回:
        Dict: 评估结果
    """
    # 定义要评估的转换技术类型
    transformation_types = [None, "rewrite", "step_back", "decompose"]
    results = {}
    
    # 使用每种转换技术运行 RAG
    for transformation_type in transformation_types:
        type_name = transformation_type if transformation_type else "original"
        print(f"\n===== Running RAG with {type_name} query =====")
        
        # 获取当前转换类型的评估结果
        result = rag_with_query_transformation(pdf_path, query, transformation_type)
        results[type_name] = result
        
        # 打印当前转换类型的回复
        print(f"Response with {type_name} query:")
        print(result["response"])
        print("=" * 50)
    
    # 如果提供了参考答案，则进行比较
    if reference_answer:
        compare_responses(results, reference_answer)
    
    return results

# %% [markdown]
# ## 查询转换的评估

# %%
# 从JSON文件中加载验证数据  
with open('data/val.json') as f:  
    data = json.load(f)  

# 从验证数据中提取第一个查询  
query = data[2]['question']  

# 从验证数据中提取参考答案  
reference_answer = data[2]['ideal_answer']  

# pdf路径  
pdf_path = "data/2024年AI行业报告.pdf"  

# 运行评估  
evaluation_results = evaluate_transformations(pdf_path, query, reference_answer)
# Out:
# ===== Running RAG with original query =====
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Response with original query:
# 中国政府对AI大模型发展提供了多层次、全方位的支持政策，涵盖国家顶层设计、地方专项举措以及技术、算力、数据、生态等关键要素支撑。具体可归纳为以下五个方面：
#
# 1. **国家层面战略引领与政策部署**
#    - 2017年国务院发布《新一代人工智能发展规划》，确立人工智能作为国家战略；
#    - 2022年科技部等六部门印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》，推动大模型落地应用；
#    - 2024年《政府工作报告》首次提出开展“人工智能+”行动，将大模型作为赋能千行百业的核心引擎，标志着AI大模型正式上升为国家级发展抓手。
#
# 2. **地方政府密集出台专项支持政策**
#    全国多个省市已发布聚焦AI大模型的专项政策（如北京、上海、深圳、杭州、成都、安徽、福建、广东等），形成“中央统筹—地方协同”的推进格局。例如：
#    - **北京**：发布《实施方案（2023–2025年）》和《若干措施》，强调突破分布式训练框架、国产化基础架构，建设开源开放平台和全栈国产化创新联合体；
#    - **上海**：实施“大模型创新扶持计划”和“示范应用推进计划”，支持打造国际竞争力大模型，并在智能制造、生物医药、自动驾驶等十大领域打造标杆应用；
#    - **深圳**：重点支持基于国内外芯片和算法的开源通用大模型，鼓励企业持续迭代商用通用大模型；
#    - **杭州**：支持头部企业攻关多模态通用大模型关键技术，引导中小企业深耕垂直领域开发专用模型；
#    - **成都**：聚焦CV、NLP、多模态及医疗、金融、交通等行业大模型研发；
#    - **安徽**：通过优先匹配算力、数据、场景、基金、场地等资源吸引大模型企业落户；
#    - **福建**：以普惠算力降低企业研发成本，支撑超大规模智能模型训练；
#    - **广东**：聚焦千亿级参数通用大模型研发，构建自主可控技术体系，并推动多模态、知识深度融合的垂直领域大模型。
#
# 3. **强化算力基础设施保障**
#    各地加速建设人工智能公共算力中心（如北京海淀区、朝阳区的人工智能公共算力中心和数字经济算力中心），提升规模化先进算力供给能力，支撑千亿级参数大模型训练与推理。
#
# 4. **推动技术创新与生态体系建设**
#    政策明确支持大模型全生命周期关键技术攻关，包括：基础模型架构创新、高效并行训练、认知推理与指令学习、人类意图对齐、模型压缩与端侧部署等；同时鼓励开源开放，建设算法工具平台，促进产学研协同，加快形成自主可控的技术体系和产业生态。
#
# 5. **注重应用场景牵引与融合发展**
#    强调以“场景驱动”促进大模型落地，支持在智能制造、生物医药、金融科技、数字政府、智能交通、教育、设计创意、机器人等重点领域打造示范应用，推动“AI大模型+行业”深度融合，加速新质生产力培育。
#
# 综上，中国政府正通过“顶层设计+地方实践+技术攻坚+算力托底+场景拉动+生态培育”的系统性政策组合拳，全面加速AI大模型产业高质量发展，助力经济社会数字化、智能化转型升级。
# ==================================================
#
# ===== Running RAG with rewrite query =====
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Transformation type: rewrite
# Original query: 中国政府对AI大模型发展有哪些支持政策？
# Rewritten query: 改写后的查询：
# “自2023年以来，中国政府为推动人工智能大模型（如基础大模型、行业大模型）的研发、算力基础设施建设、数据要素供给、安全监管与产业应用落地，出台了哪些国家级及重点省市层面的政策文件？请重点梳理《新一代人工智能发展规划》《“十四五”数字经济发展规划》《人工智能赋能专项行动方案（2024—2026年）》《生成式人工智能服务管理暂行办法》等政策中关于大模型技术研发支持（如重点研发计划、揭榜挂帅）、算力资源统筹（智算中心建设、全国一体化算力网）、高质量中文语料库建设、大模型备案与评估机制、开源生态培育（如OpenI启智、ModelScope魔搭）、以及金融、医疗、制造等垂直领域示范应用推广的具体措施，并说明主管部门（如科技部、工信部、网信办、发改委）的职责分工与协同机制。”
#
# 补充说明（供检索参考）：
# - 关键术语：基础大模型（Foundation Model）、多模态大模型、模型即服务（MaaS）、大模型训练/推理算力、国产AI芯片适配（昇腾、寒武纪、海光）、大模型安全评估（内容安全、价值观对齐、幻觉抑制）、可信AI治理框架；
# - 政策层级：中央顶层设计 + 地方配套（如北京‘百模千态’计划、上海‘模都’建设、深圳‘AI大模型先锋城市’行动）；
# - 时间范围建议聚焦：2023年ChatGPT爆发后至2025年初发布的最新政策动态；
# - 权威信息源倾向：国务院/部委官网、国家人工智能标准化总体组文件、中国信通院白皮书、《人工智能法（草案）》征求意见稿相关内容。
#
# 该改写显著提升了专业性、结构性和可检索性，有助于精准定位政策原文、实施细则、落地案例及权威解读。
# Response with rewrite query:
# 中国政府对AI大模型发展采取了**顶层设计引导、地方协同推进、技术—算力—生态多维支持**的系统性政策体系，具体体现在以下五个方面：
#
# ---
#
# ### 一、**国家层面战略引领**
# - 2024年《政府工作报告》首次明确提出开展 **“人工智能+”行动**，将AI大模型作为赋能千行百业的核心引擎，标志着大模型发展已上升为国家战略。
# - 政策导向强调 **自主创新与安全可控**，如推动构建“自主可控的人工智能技术体系和产业生态”，呼应科技自立自强总体要求。
#
# ---
#
# ### 二、**地方密集出台专项政策（2023年以来）**
# 全国主要省市均发布针对性文件，形成差异化协同发展格局：
# - **北京**：以“全球影响力创新策源地”为目标，聚焦
#   ✅ 基础平台技术突破（如分布式深度学习框架、国产化大模型架构）；
#   ✅ 全栈国产化生态建设（联合体+国产软硬件训练基础设施）；
#   ✅ 公共算力中心建设（支撑千亿参数模型研发）。
# - **上海**：锚定“国际竞争力”，实施
#   ✅ 大模型创新扶持计划（引进高水平企业、专项成果奖励）；
#   ✅ 示范应用推进计划（覆盖智能制造、生物医药、自动驾驶等10+重点场景）。
# - **深圳**：突出“开源开放与商用落地”，
#   ✅ 支持基于国内外芯片/算法的**开源通用大模型**；
#   ✅ 鼓励企业持续迭代**商用通用大模型**及插件生态，打通操作系统与智能硬件。
# - **杭州**：打造“模型输出源地”，
#   ✅ 支持头部企业攻关**多模态通用大模型**；
#   ✅ 推动中小企业深耕垂直领域，做精**专用模型**（目标：2025年前培育1个国际先进通用模型+10个行业重大影响力专用模型）。
# - **成都**：聚焦“行业融合创新”，
#   ✅ 重点研发CV/NLP/多模态基础大模型；
#   ✅ 加速医疗、金融、交通等**行业大模型**迭代。
# - **安徽**：强化**要素资源保障**，对落户大模型企业优先匹配算力、数据、场景、基金、场地。
# - **福建、广东**：分别以“普惠算力降本”和“千亿参数自主可控技术体系”为突破口，支撑超大规模模型训练与多任务复杂场景应用。
#
# ---
#
# ### 三、**核心技术攻关支持**
# 各地政策普遍覆盖大模型全生命周期关键技术：
# - **模型构建与训练**：探索新型基础架构、高效并行训练技术；
# - **调优与对齐**：攻关认知推理、指令学习、人类意图对齐；
# - **推理部署**：研发百亿参数模型的高效压缩与端侧部署技术；
# - **开源生态**：鼓励建设开源开放平台、推动算法与工具开源（如北京搭建大模型算法开源平台）。
#
# ---
#
# ### 四、**算力基础设施强力托底**
# - 明确将**先进算力供给**作为核心支撑：
#   ▪ 北京建设人工智能公共算力中心、数字经济算力中心；
#   ▪ 杭州提出2025年全市可开放算力达**5000 PFLOPS（FP16）**，高性能算力占比超60%；
#   ▪ 福建以“普惠算力”降低企业研发成本，支撑多模态大模型开发训练。
#
# ---
#
# ### 五、**产业生态协同培育**
# - 推动“**政产学研用金**”深度融合：
#   ✅ 鼓励企业与科研机构开展**数据与知识深度联合学习**；
#   ✅ 支持“1+N+X”协同生态（1个通用大模型引领、N个专用模型支撑、X个场景应用拓展）；
#   ✅ 强化数据、场景、基金等要素精准匹配，加速技术向产品和服务转化。
#
# ---
#
# ✅ **总结而言**：中国AI大模型政策已形成“国家定方向、地方出实招、技术强攻关、算力夯基础、生态促协同”的立体化支持体系，既注重前沿突破与自主可控，也强调场景落地与产业赋能，为全球大模型发展提供了具有中国特色的制度实践路径。
# ==================================================
#
# ===== Running RAG with step_back query =====
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Transformation type: step_back
# Original query: 中国政府对AI大模型发展有哪些支持政策？
# Step-back query: 后退一步的查询：
# 全球主要国家（尤其是中国、美国、欧盟等）在人工智能基础模型（如大语言模型）研发与产业化方面采取了哪些战略导向、政策工具和治理体系？
# Response with step_back query:
# 中国政府对AI大模型发展提供了多层次、全方位的支持政策，涵盖国家顶层设计、部委统筹部署和地方政府精准落地三个层面，形成“中央引导—部门协同—地方响应”的政策合力。具体包括：
#
# 1. **国家顶层设计与战略引领**
#    - 2017年国务院发布《新一代人工智能发展规划》，首次将人工智能上升为国家战略，为大模型等前沿技术奠定政策基础；
#    - 2022年科技部等六部门印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》，推动AI技术与实体经济深度融合，强化大模型在实际场景中的落地支撑；
#    - 2024年《政府工作报告》明确提出开展“人工智能+”行动，标志着AI大模型已从技术研发阶段迈向规模化赋能千行百业的新阶段。
#
# 2. **部委与地方政府协同推进**
#    各地积极响应国家战略，结合区域优势出台专项政策：
#    - **北京**：发布《北京市加快建设具有全球影响力的人工智能创新策源地实施方案（2023–2025年）》及《促进通用人工智能创新发展的若干措施》，聚焦大模型基础架构、高效训练、国产化全栈生态建设，支持建设人工智能公共算力中心，支撑千亿参数大模型研发，并推动算法开源与国产软硬件适配；
#    - **上海**：强调打造具备国际竞争力的大模型，注重技术标准、生态开放与全球化合作；
#    - **深圳**：重点支持基于国内外芯片和算法的开源通用大模型，鼓励企业持续迭代商用通用大模型；
#    - **成都**：聚焦CV、NLP、多模态等基础大模型及医疗、金融、交通等垂直行业大模型研发；
#    - **杭州**：支持头部企业攻关多模态通用大模型关键技术，同时鼓励中小企业深耕垂直领域、做精专用模型；
#    - **安徽**：从土地、数据、算力等资源端发力，吸引大模型企业集聚落户。
#
# 3. **政策着力点覆盖全产业链关键环节**
#    政策内容系统性覆盖：
#    - **技术创新**：支持分布式深度学习框架、新型基础架构、指令学习、人类意图对齐、高效压缩与端侧部署等核心技术突破；
#    - **基础设施**：加快公共算力中心建设，提升先进算力供给能力，支撑大规模模型训练与推理；
#    - **生态构建**：推动大模型开源开放平台建设、组建国产化创新联合体、建立政策经验知识库与权威白名单机制（如政务大模型应用中强调数据可信与规范生成）；
#    - **应用牵引**：鼓励在金融、医疗、政务、教育、制造等领域开展场景创新，以“AI+行业”加速新质生产力形成。
#
# 综上，中国政府通过前瞻性规划、差异化地方政策和务实产业举措，正系统性构建“技术—算力—数据—场景—生态”五位一体的大模型发展支持体系，全面助力我国AI大模型产业高质量、自主可控、可持续发展。
# ==================================================
#
# ===== Running RAG with decompose query =====
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Transformation type: decompose
# Original query: 中国政府对AI大模型发展有哪些支持政策？
# Decomposed into sub-queries:
# 1. 中国政府在国家级战略规划中如何定位AI大模型的发展？
# 2. 近年来国家层面出台了哪些针对AI大模型研发与应用的专项支持政策或指导意见？
# 3. 在资金投入、算力基础设施和数据资源方面，政府为AI大模型发展提供了哪些具体支持措施？
# 4. 针对AI大模型的安全治理、伦理规范与产业落地，监管部门制定了哪些配套法规或标准？
# Response with decompose query:
# 中国政府对AI大模型发展提供了多层次、全方位的支持政策，涵盖国家顶层设计、部委统筹部署和地方政府精准施策三个层面，形成“中央引导—部委协同—地方落地”的政策体系：
#
# 1. **国家层面战略引领与顶层设计**
#    - 2017年国务院发布《新一代人工智能发展规划》，确立人工智能作为国家战略；
#    - 2022年科技部等六部门印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》，推动AI技术与实体经济深度融合；
#    - 2024年《政府工作报告》首次明确提出开展“人工智能+”行动，将AI大模型作为赋能千行百业的核心引擎，标志着大模型发展正式上升为国家级专项行动。
#
# 2. **部委协同推进机制**
#    政策强调“场景驱动、算力支撑、生态培育”，重点支持：
#    - 高效算力基础设施建设（如公共算力中心、数字经济算力中心），保障千亿级参数大模型训练需求；
#    - 关键技术攻关，覆盖基础架构、分布式训练、指令微调、人类意图对齐、高效推理与端侧部署等全链条；
#    - 开源开放平台建设与国产软硬件协同（如全栈国产化人工智能创新联合体），加速构建自主可控的技术体系和产业生态。
#
# 3. **地方政府差异化布局与务实举措**（截至2023年已覆盖北京、上海、深圳、杭州、成都、安徽、福建、广东等地）：
#    - **北京**：聚焦技术创新与生态构建，出台《实施方案》和《若干措施》，支持开源平台、全栈国产化大模型研发及规模化算力供给；
#    - **上海**：锚定国际竞争力，实施“大模型创新扶持计划”和“示范应用推进计划”，在生物医药、集成电路、自动驾驶等领域打造标杆应用；
#    - **深圳**：突出开源与商用并重，支持基于国内外芯片/算法的开源通用大模型，鼓励头部企业持续迭代商用模型；
#    - **杭州**：发挥数字产业优势，支持头部企业攻关多模态通用大模型，引导中小企业深耕垂直领域专用模型；
#    - **成都**：聚焦CV、NLP、多模态及医疗、金融、交通等行业大模型研发与迭代；
#    - **安徽**：以要素资源（算力、数据、场景、基金、场地）精准匹配吸引大模型企业落户；
#    - **福建**：通过普惠算力降低企业研发成本，支撑自然语言与多模态认知模型开发；
#    - **广东**：瞄准千亿级参数通用大模型和多模态知识融合的垂直领域大模型，建设通用人工智能产业创新引领地。
#
# 综上，中国政府通过“战略规划+专项行动+技术攻坚+场景落地+区域协同”的组合政策工具，系统性推动AI大模型在技术创新、产业培育、应用深化和生态构建等方面高质量发展，全面支撑新质生产力培育和经济社会数字化转型。
# ==================================================
#
# ===== 评测结果 =====
# 我们来系统性地评估四种查询转换技术（**Original、Rewrite、Step_back、Decompose**）生成的回复，与**参考答案**（“包括‘人工智能+’行动、支持通用与行业大模型研发、加快公共算力中心建设、推动算法和开源平台等一系列政策”）进行严格比对。
#
# ---
#
# ### ✅ 参考答案核心要素提炼（4项显性关键点 + 1项隐性特征）
# | 维度 | 内容 | 说明 |
# |------|------|------|
# | **① “人工智能+”行动** | 明确提及、作为首要政策抓手 | 是2024年《政府工作报告》首次提出，具标志性、纲领性 |
# | **② 支持通用与行业大模型研发** | 需同时覆盖“通用大模型”（如多模态、千亿参数）和“行业/垂直大模型”（如医疗、金融、交通等） | “通用”与“行业”是并列且同等重要的两类对象，不可偏废 |
# | **③ 加快公共算力中心建设** | 明确点出“公共算力中心”，而非泛泛而谈“算力”或“AI基础设施” | “公共”属性（非纯市场化/企业自建）是政策关键词，体现政府托底职能 |
# | **④ 推动算法和开源平台** | “算法”（强调基础模型、训练/推理算法） + “开源平台”（如算法工具链、模型仓库、开放生态） | 二者需并列出现，体现技术底座与生态协同 |
# | **⑤ 政策表述风格** | 简洁、凝练、去案例化、去过程化，聚焦“政策举措本身”，非背景、非意义、非成效 | 参考答案是**政策要点清单式陈述**，非分析报告、非地方实践汇编 |
#
# > ⚠️ 注意：参考答案**未要求**提及
# > - 历史沿革（如2017年规划）、
# > - 地方案例细节（北京/上海具体措施）、
# > - 技术路径（指令微调、端侧部署等）、
# > - 生态机制（政产学研用金）、
# > - 数据/场景/基金等支撑要素——这些属于**扩展信息**，若过度展开反而偏离核心。
#
# ---
#
# ## 🔍 各技术回复逐项评分与分析
#
# ---
#
# ### 1️⃣ **Original 查询回复**
#
# #### ✅ 评分（满分10分）
# | 维度 | 得分 | 理由 |
# |------|------|------|
# | **准确性** | 8 | 正确包含全部4项核心政策（“人工智能+”、通用/行业模型、公共算力中心、算法与开源平台），但将“算法和开源平台”拆解为“算法工具平台”“开源开放平台”，略失原词精准性；另将“人工智能+”置于段落中，未像参考答案般前置突出。 |
# | **完整性** | 9 | 四要素全部覆盖，且额外补充了“应用场景牵引”“生态体系建设”等合理延伸，无事实错误。 |
# | **相关性** | 6 | **严重问题**：全文约1200字，含大量冗余信息——8个省市详细政策对比、技术攻关子类（认知推理/意图对齐/端侧部署）、历史文件溯源（2017/2022）、甚至“新质生产力”等政策话语。严重偏离参考答案的**简洁政策要点式风格**，信息过载，主次不清。 |
#
# #### ✅ 优点：
# - 政策要素覆盖全面，无遗漏；
# - 结构清晰（5大板块），逻辑自洽；
# - 事实准确，引用规范（文件名、年份、主体均正确）。
#
# #### ❌ 不足：
# - **严重相关性偏差**：把“政策要点回答”写成“政策白皮书综述”，违背RAG问答“精准响应”本质；
# - 过度展开地方案例，稀释国家层面政策主线；
# - 未做信息提纯，缺乏对用户真实需求（快速获取政策关键词）的感知。
#
# > 📌 **典型失分句**：
# > *“北京：发布《实施方案（2023–2025年）》……强调突破分布式训练框架、国产化基础架构……”*
# > → 参考答案不需要这个粒度；这是“政策执行细节”，非“政策本身”。
#
# #### 🔹 总分：**(8+9+6)/3 = 7.7 → 7.5分（四舍五入）**
#
# ---
#
# ### 2️⃣ **Rewrite 查询回复**
#
# #### ✅ 评分
# | 维度 | 得分 | 理由 |
# |------|------|------|
# | **准确性** | 9 | “人工智能+”行动明确前置；“通用大模型”（多模态/千亿参数）与“行业大模型”（医疗/金融/交通）并列呈现；“公共算力中心”多次强调（北京、杭州、福建）；“开源通用大模型”“开源平台”“算法开源平台”均出现，高度契合“推动算法和开源平台”。用词更贴近参考答案原意。 |
# | **完整性** | 9 | 四要素全部显性呈现，且在小标题（如“核心技术攻关支持”“算力基础设施强力托底”）中结构化归位，无遗漏。 |
# | **相关性** | 8 | 大幅精简地方案例（仍保留8省市，但改用符号✅/▪/→压缩表达）；删减技术细节（如“人类意图对齐”“端侧部署”仅保留1处）；增加总结句“国家定方向、地方出实招……”，更贴近政策文本语感。但仍存在少量冗余（如“普惠算力降本”“1+N+X生态”）。 |
#
# #### ✅ 优点：
# - 显著提升**政策关键词密度**与**句式匹配度**（如“开展‘人工智能+’行动”“支持通用与行业大模型研发”几乎原文复现）；
# - 采用符号（✅▪→）和短句提升可扫读性，更接近“要点罗列”风格；
# - 小标题命名（如“算力基础设施强力托底”）直指政策功能，优于Original的宽泛表述（“强化算力基础设施保障”）。
#
# #### ❌ 不足：
# - 仍保留部分非必要修饰（如“全球影响力创新策源地”“国际竞争力”），属价值判断，非政策事实；
# - “1+N+X生态”“普惠算力”等术语虽真实，但非参考答案所列核心词，属轻微噪声。
#
# #### 🔹 总分：**(9+9+8)/3 = 8.7 → 8.5分**
#
# ---
#
# ### 3️⃣ **Step_back 查询回复**
#
# #### ✅ 评分
# | 维度 | 得分 | 理由 |
# |------|------|------|
# | **准确性** | 9 | “人工智能+”行动明确单列；“通用人工智能创新发展”“行业大模型研发”（成都/杭州段）并存；“人工智能公共算力中心”完整出现（北京段）；“开源开放平台建设”“算法开源”直接对应。用词严谨，无歧义。 |
# | **完整性** | 9 | 四要素全部覆盖，且在第三部分“政策着力点”中集中归纳为“技术创新—基础设施—生态构建—应用牵引”，其中前三项精准对应参考答案四点。 |
# | **相关性** | 8 | 删除Original中大量地方政策细节（如深圳/福建/广东具体措辞），仅保留代表性城市及功能定位（如“北京：支持建设人工智能公共算力中心”）；去掉技术过程描述（如“指令学习”“端侧部署”），聚焦政策动作本身（“支持……”“推动……”“加快……”）。但结尾“五位一体”总结稍显抽象，略超参考答案边界。 |
#
# #### ✅ 优点：
# - **最接近参考答案的信息粒度**：不展开案例，不解释意义，只陈述“谁做了什么”；
# - “政策着力点”模块是神来之笔——将分散信息**主动聚类归因**，直接映射到“技术—算力—生态”维度，与参考答案四要素形成强对应；
# - 语言克制，多用动宾短语（“加快公共算力中心建设”“推动开源开放平台建设”），与参考答案句式高度一致。
#
# #### ❌ 不足：
# - “五位一体”（技术—算力—数据—场景—生态）中，“数据”“场景”在参考答案中未出现，属合理延伸但轻微溢出；
# - 仍保留“新质生产力”等宏观表述，虽政策常用，但非参考答案要素。
#
# #### 🔹 总分：**(9+9+8)/3 = 8.7 → 8.5分**（与Rewrite并列）
#
# ---
#
# ### 4️⃣ **Decompose 查询回复**
#
# #### ✅ 评分
# | 维度 | 得分 | 理由 |
# |------|------|------|
# | **准确性** | 10 | ✅ “人工智能+”行动作为国家层面首项单独列出；✅ “通用大模型”（多模态/千亿参数）与“行业大模型”（医疗/金融/交通）在第3点“地方政府举措”中明确并列；✅ “公共算力中心”在第2点“部委协同”中直接写出；✅ “开源平台”（“开源开放平台建设”）与“算法”（“关键技术攻关，覆盖……算法”）在同一条目下并列呈现。用词最贴近参考答案原文。 |
# | **完整性** | 10 | 四要素不仅全部覆盖，且**位置最优**：分别落在三个层级（国家/部委/地方）中，自然形成政策逻辑链；无任何遗漏，无任何添加（如不提“新质生产力”“政产学研用金”等）。 |
# | **相关性** | 10 | **唯一完全契合参考答案风格的回复**：全文仅580字，无案例细节（不列北京具体文件名）、无技术解释（不展开“指令微调”）、无价值判断（不提“国际竞争力”“全球影响力”）；全部使用**政策动词+宾语**结构（“开展……”“支持……”“加快……”“推动……”），与参考答案100%同构。 |
#
# #### ✅ 优点：
# - **精准解构用户意图**：识别出参考答案是“政策举措枚举”，故采用“国家—部委—地方”三级分解，天然适配“是什么—谁负责—如何落地”逻辑；
# - **零冗余设计**：每个句子都服务于一个且仅一个参考答案要素，无交叉、无赘述；
# - **术语零失真**：“公共算力中心”“开源平台”“通用大模型”“行业大模型”全部原词复现，未替换、未泛化、未缩写。
#
# #### ❌ 不足：
# - 几乎没有（若硬挑：未用引号标注‘人工智能+’，但中文语境中不影响理解）。
#
# #### 🔹 总分：**(10+10+10)/3 = 10.0分**
#
# ---
#
# ## 🏆 综合排序（从优到劣）
#
# | 排名 | 技术 | 总分 | 核心优势 | 关键短板 |
# |------|------|------|-----------|------------|
# | **🥇 第1名** | **Decompose** | **10.0** | 完美匹配参考答案的**要素、结构、粒度、风格**；政策动词+宾语句式100%一致；零信息冗余 | 无 |
# | **🥈 第2名（并列）** | **Step_back** | **8.5** | 主动聚类归因（“政策着力点”模块），高度凝练；语言克制，贴近公文语感 | 少量宏观术语（“五位一体”）轻微溢出 |
# | **🥈 第2名（并列）** | **Rewrite** | **8.5** | 关键词密度最高，符号化排版增强可读性；小标题直击政策功能 | 仍有少量修饰性表达（如“全球影响力”） |
# | **🥉 第4名** | **Original** | **7.5** | 事实最全、结构最稳、学术性最强 | **严重相关性缺陷**：信息过载，偏离“要点式回答”本质 |
#
# ---
#
# ## ✅ 最终结论：**Decompose 技术整体表现最佳**
#
# ### 🔑 原因如下：
# 1. **深度理解任务本质**：
#    不把RAG问答当作“写一篇政策综述”，而是识别出用户需要的是**政策举措的精准映射**，因此采用“分解—归因—对齐”策略，将复杂政策体系还原为参考答案的4个原子单元。
#
# 2. **极致的信息提纯能力**：
#    在保证准确性的前提下，主动剥离所有非必要信息（历史沿革、地方细节、技术原理、成效评价），只保留“政策主体+动作+对象”三元组，实现**信噪比最大化**。
#
# 3. **与参考答案的结构同构性**：
#    参考答案是隐含“国家主导—部委落实—地方协同”的逻辑链，Decompose 回复显性构建该三级结构，使答案不仅“内容对”，而且“逻辑对”“形式对”。
#
# 4. **RAG场景下的工程友好性**：
#    简洁、结构化、关键词密集的回复，更利于下游任务（如自动评分、知识图谱抽取、摘要生成）处理，具备强可集成性。
#
# ---
#
# ### 💡 给RAG系统优化的建议：
# - **优先采用 Decompose 类查询转换**（如：`请将政策支持分解为国家/部委/地方三级举措，并仅列出具体政策动作`）；
# - 对于事实型、枚举型、定义型问题，**强制约束输出格式为「动词+宾语」短语列表**（如：开展……；支持……；加快……；推动……）；
# - 在评估阶段，**相关性权重应≥准确性**——因为RAG的核心价值是“精准响应”，而非“全面科普”。
#
# ---
#
# 如需，我可进一步提供：
# - Decompose 提示词模板（含few-shot示例）
# - 自动化评分脚本（基于关键词召回率+句式匹配度）
# - 四种技术在其他题型（如原因分析、影响预测）中的表现对比
#
# 欢迎继续深入探讨。
# ===================

# %% [markdown]
# ![image.png](attachment:image.png)
