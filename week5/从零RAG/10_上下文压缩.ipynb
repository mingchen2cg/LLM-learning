# %% [markdown]
# # 增强RAG系统的上下文压缩
# 本笔记实现了一种上下文压缩技术以提高RAG系统效率。我们将过滤并压缩检索到的文本块，仅保留最相关的内容，从而减少噪声并提升回复质量。
#
# 在为RAG检索文档时，通常会得到包含相关和不相关信息的片段。上下文压缩帮助我们：
#
# - 移除无关的句子和段落
# - 仅关注与查询相关的信息
# - 最大化上下文窗口中的有用信号
#
# 让我们从头开始实现这一方法！

# %% [markdown]
# ![image.png](attachment:ccbc624b-a76b-4365-aad9-fe42fddf104c.png)

# %% [markdown]
# ## 环境设置
# 我们首先导入必要的库。

# %%
import fitz  # PyMuPDF，用于处理 PDF 文件
import os  # 操作系统相关功能，如文件路径管理
import numpy as np  # NumPy，用于数值计算
import json  # JSON 数据处理
from openai import OpenAI  # OpenAI API 客户端

# %% [markdown]
# ## 从PDF文件中提取文本
# 为了实现RAG（Retrieval-Augmented Generation，检索增强生成），我们首先需要一个文本数据源。在此场景下，我们使用PyMuPDF库从PDF文件中提取文本。

# %%
def extract_text_from_pdf(pdf_path):
    """
    从PDF文件中提取文本并打印前`num_chars`个字符。

    参数:
    pdf_path (str): PDF文件的路径。

    返回:
    str: 从PDF中提取的文本。
    """
    # 打开PDF文件
    mypdf = fitz.open(pdf_path)
    all_text = ""  # 初始化一个空字符串用于存储提取的文本

    # 遍历PDF中的每一页
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]  # 获取页面
        text = page.get_text("text")  # 从页面提取文本
        all_text += text  # 将提取的文本追加到all_text字符串中

    return all_text  # 返回提取的文本

# %% [markdown]
# ## 提取文本的分块
# 一旦提取了文本，我们将其划分为更小的、相互重叠的块，以提高检索准确性。

# %%
def chunk_text(text, n=1000, overlap=200):
    """
    将给定文本分割为每段包含 n 个字符且具有 overlap 的片段。

    参数:
    text (str): 需要分割的文本。
    n (int): 每个片段的字符数量。
    overlap (int): 相邻片段之间的重叠字符数量。

    返回:
    List[str]: 一个包含文本片段的列表。
    """
    chunks = []  # 初始化一个空列表用于存储片段
    
    # 使用 (n - overlap) 的步长遍历文本
    for i in range(0, len(text), n - overlap):
        # 将从索引 i 到 i + n 的文本片段追加到 chunks 列表中
        chunks.append(text[i:i + n])

    return chunks  # 返回文本片段列表

# %% [markdown]
# ## 初始化OpenAI API客户端
# 我们初始化OpenAI客户端以生成嵌入向量（embeddings）和回复。

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # 加载.env文件
api_key = os.getenv("DASHSCOPE_API_KEY")  # 读取密钥
base_url = os.getenv("base_url")
# 初始化 OpenAI 客户端，设置基础 URL 和 API 密钥
client = OpenAI(
    base_url=base_url,
    api_key=api_key,  # 从环境变量中获取 API 密钥
)

# %% [markdown]
# ## 构建一个简单的向量存储库
# 由于我们不能使用FAISS，让我们实现一个简单的向量存储库。

# %%
class SimpleVectorStore:
    """
    一个使用NumPy实现的简单向量存储。
    """
    def __init__(self):
        """
        初始化向量存储。
        """
        self.vectors = []  # 存储嵌入向量的列表
        self.texts = []  # 存储原始文本的列表
        self.metadata = []  # 存储每个文本元数据的列表
    
    def add_item(self, text, embedding, metadata=None):
        """
        向向量存储中添加一个项目。

        参数:
        text (str): 原始文本。
        embedding (List[float]): 嵌入向量。
        metadata (dict, 可选): 额外的元数据。
        """
        self.vectors.append(np.array(embedding))  # 将嵌入转换为numpy数组并添加到向量列表中
        self.texts.append(text)  # 将原始文本添加到文本列表中
        self.metadata.append(metadata or {})  # 添加元数据到元数据列表中，如果为None则使用空字典
    
    def similarity_search(self, query_embedding, k=5):
        """
        查找与查询嵌入最相似的项目。

        参数:
        query_embedding (List[float]): 查询嵌入向量。
        k (int): 返回的结果数量。

        返回:
        List[Dict]: 最相似的k个项目及其文本和元数据。
        """
        if not self.vectors:
            return []  # 如果没有存储向量，则返回空列表
        
        # 将查询嵌入转换为numpy数组
        query_vector = np.array(query_embedding)
        
        # 使用余弦相似度计算相似性
        similarities = []
        for i, vector in enumerate(self.vectors):
            similarity = np.dot(query_vector, vector) / (np.linalg.norm(query_vector) * np.linalg.norm(vector))
            similarities.append((i, similarity))  # 将索引和相似度分数添加到列表中
        
        # 按相似度降序排序
        similarities.sort(key=lambda x: x[1], reverse=True)
        
        # 返回前k个结果
        results = []
        for i in range(min(k, len(similarities))):
            idx, score = similarities[i]
            results.append({
                "text": self.texts[idx],  # 添加对应索引的文本
                "metadata": self.metadata[idx],  # 添加对应索引的元数据
                "similarity": score  # 添加相似度分数
            })
        
        return results  # 返回前k个结果的列表

# %% [markdown]
# ## 嵌入生成

# %%
def create_embeddings(text, model="text-embedding-v4"):
    """
    使用指定的模型为给定文本创建嵌入。

    参数:
    text (str): 需要创建嵌入的输入文本。
    model (str): 用于创建嵌入的模型。

    返回:
    List[float]: 嵌入向量。
    """
    # 1. 统一转换为列表进行批处理计算
    input_text = [text] if isinstance(text, str) else text

    max_batch_size = 10
    all_embeddings = []

    # 2. 按照每 10 个一组进行分批请求，避免触发 API 限制
    for i in range(0, len(input_text), max_batch_size):
        batch = input_text[i : i + max_batch_size]
        response = client.embeddings.create(model=model, input=batch)
        # 将当前批次的结果提取并合并
        all_embeddings.extend([item.embedding for item in response.data])

    # 3. 严格遵循原有的返回逻辑：
    # 如果输入是字符串，则返回第一个嵌入向量 (List[float])
    if isinstance(text, str):
        return all_embeddings[0]

    # 否则，返回所有嵌入向量的列表 (List[List[float]])
    return all_embeddings

# %% [markdown]
# ## 构建我们的文档处理管道

# %%
def process_document(pdf_path, chunk_size=1000, chunk_overlap=200):
    """
    处理文档以供RAG使用。

    参数:
    pdf_path (str): PDF文件的路径。
    chunk_size (int): 每个块的字符大小。
    chunk_overlap (int): 块之间的重叠字符数。

    返回:
    SimpleVectorStore: 包含文档块及其嵌入的向量存储。
    """
    # 从PDF文件中提取文本
    print("Extracting text from PDF...")
    extracted_text = extract_text_from_pdf(pdf_path)
    
    # 将提取的文本分割为更小的片段
    print("Chunking text...")
    chunks = chunk_text(extracted_text, chunk_size, chunk_overlap)
    print(f"Created {len(chunks)} text chunks")
    
    # 为每个文本块创建嵌入
    print("Creating embeddings for chunks...")
    chunk_embeddings = create_embeddings(chunks)
    
    # 初始化一个简单的向量存储来存储块及其嵌入
    store = SimpleVectorStore()
    
    # 将每个块及其对应的嵌入添加到向量存储中
    for i, (chunk, embedding) in enumerate(zip(chunks, chunk_embeddings)):
        store.add_item(
            text=chunk,
            embedding=embedding,
            metadata={"index": i, "source": pdf_path}
        )
    
    print(f"Added {len(chunks)} chunks to the vector store")
    return store

# %% [markdown]
# ## 实现上下文压缩
# 这是我们方法的核心——我们将使用大型语言模型（LLM）来过滤和压缩检索到的内容。

# %%
def compress_chunk(chunk, query, compression_type="selective", model="qwen-plus"):
    """
    压缩从检索中获取的文本块，仅保留与查询相关的内容。

    参数:
        chunk (str): 要压缩的文本块
        query (str): 用户查询
        compression_type (str): 压缩类型（"selective"、"summary" 或 "extraction"）
        model (str): 使用的LLM模型

    返回:
        str: 压缩后的文本块
    """
    # 定义不同压缩方法的系统提示
    if compression_type == "selective":
        system_prompt = """你是一位信息过滤专家。你的任务是分析文档片段，并仅提取与用户查询直接相关的句子或段落。删除所有不相关的内容。

        你的输出应当：
        1. 仅包含有助于回答查询的文本
        2. 保留相关句子的原始措辞（不要改写）
        3. 保持文本的原始顺序
        4. 包含所有相关内容，即使看起来冗余
        5. 排除任何不相关的文本

        请将你的回答格式化为纯文本，不要添加额外的评论。"""
    elif compression_type == "summary":
        system_prompt = """你是一位摘要专家。你的任务是创建一个简洁的摘要，专注于与用户查询相关的信息。

        你的输出应当：
        1. 简明扼要地涵盖与查询相关的信息
        2. 仅关注与查询相关的信息
        3. 省略不相关的细节
        4. 以中立、事实的语气撰写

        请将你的回答格式化为纯文本，不要添加额外的评论。"""
    else:  # extraction
        system_prompt = """你是一位信息提取专家。你的任务是从文档片段中仅提取包含与用户查询相关信息的句子。

        你的输出应当：
        1. 仅包含原文中与查询直接相关的句子
        2. 保留原始措辞（不要修改文本）
        3. 仅包含与查询直接相关的句子
        4. 用换行符分隔提取的句子
        5. 不要添加任何评论或额外文本

        请将你的回答格式化为纯文本，不要添加额外的评论。"""

    # 定义带有查询和文档片段的用户提示
    user_prompt = f"""
        查询: {query}

        文档片段:
        {chunk}

        仅提取与回答此查询相关的内容。
    """

    # 使用OpenAI API生成回复
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0
    )

    # 从回复中提取压缩后的文本块
    compressed_chunk = response.choices[0].message.content.strip()

    # 计算压缩率
    original_length = len(chunk)
    compressed_length = len(compressed_chunk)
    compression_ratio = (original_length - compressed_length) / original_length * 100

    return compressed_chunk, compression_ratio

# %% [markdown]
# ## 批量压缩的实现
# 为了提高效率，只要有可能，我们会一次性压缩多个数据块。

# %%
def batch_compress_chunks(chunks, query, compression_type="selective", model="qwen-plus"):
    """
    分别压缩多个片段。

    参数:
        chunks (List[str]): 待压缩的文本片段列表
        query (str): 用户查询
        compression_type (str): 压缩类型（"selective"、"summary" 或 "extraction"）
        model (str): 使用的LLM模型

    返回:
        List[Tuple[str, float]]: 包含压缩片段及其压缩比率的列表
    """
    print(f"Compressing {len(chunks)} chunks...")  # 打印即将压缩的片段数量
    results = []  # 初始化一个空列表来存储结果
    total_original_length = 0  # 初始化变量以存储原始片段的总长度
    total_compressed_length = 0  # 初始化变量以存储压缩片段的总长度

    # 遍历每个片段
    for i, chunk in enumerate(chunks):
        print(f"Compressing chunk {i+1}/{len(chunks)}...")  # 打印压缩进度
        # 压缩片段并获取压缩后的片段和压缩比率
        compressed_chunk, compression_ratio = compress_chunk(chunk, query, compression_type, model)
        results.append((compressed_chunk, compression_ratio))  # 将结果追加到结果列表中

        total_original_length += len(chunk)  # 将原始片段的长度累加到总原始长度
        total_compressed_length += len(compressed_chunk)  # 将压缩片段的长度累加到总压缩长度

    # 计算总体压缩比率
    overall_ratio = (total_original_length - total_compressed_length) / total_original_length * 100
    print(f"Overall compression ratio: {overall_ratio:.2f}%")  # 打印总体压缩比率

    return results  # 返回包含压缩片段及其压缩比率的列表

# %% [markdown]
# ## 回复生成函数

# %%
def generate_response(query, context, model="qwen-plus"):
    """
    根据查询和上下文生成回复。
    
    参数:
        query (str): 用户的查询
        context (str): 来自压缩块的上下文文本
        model (str): 使用的语言模型
        
    返回:
        str: 生成的回复
    """
    # 定义系统提示以指导AI的行为
    system_prompt = """你是一位乐于助人的AI助手。仅根据提供的上下文回答用户的问题。
    如果在上下文中找不到答案，请说明信息不足。"""
            
    # 创建用户提示，通过组合上下文和查询生成
    user_prompt = f"""
        上下文:
        {context}

        问题: {query}

        请仅根据上述上下文提供全面的回答。
    """
    
    # 使用OpenAI API生成回复
    response = client.chat.completions.create(
        model=model,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0
    )
    
    # 返回生成的回复内容
    return response.choices[0].message.content

# %% [markdown]
# ## 完整的RAG管道与上下文压缩

# %%
def rag_with_compression(pdf_path, query, k=10, compression_type="selective", model="qwen-plus"):
    """
    带上下文压缩的RAG管道完整实现。
    
    参数:
        pdf_path (str): PDF文档的路径
        query (str): 用户查询
        k (int): 初始检索的片段数量
        compression_type (str): 压缩类型
        model (str): 使用的LLM模型
        
    返回:
        dict: 包含查询、压缩片段和回复的结果字典
    """
    print("\n=== RAG WITH CONTEXTUAL COMPRESSION ===")
    print(f"Query: {query}")
    print(f"Compression type: {compression_type}")
    
    # 处理文档以提取文本、分块并创建嵌入
    vector_store = process_document(pdf_path)
    
    # 为查询创建嵌入
    query_embedding = create_embeddings(query)
    
    # 根据查询嵌入检索最相似的k个片段
    print(f"Retrieving top {k} chunks...")
    results = vector_store.similarity_search(query_embedding, k=k)
    retrieved_chunks = [result["text"] for result in results]
    
    # 对检索到的片段应用压缩
    compressed_results = batch_compress_chunks(retrieved_chunks, query, compression_type, model)
    compressed_chunks = [result[0] for result in compressed_results]
    compression_ratios = [result[1] for result in compressed_results]
    
    # 过滤掉所有空的压缩片段
    filtered_chunks = [(chunk, ratio) for chunk, ratio in zip(compressed_chunks, compression_ratios) if chunk.strip()]
    
    if not filtered_chunks:
        # 如果所有片段都被压缩为空字符串，则使用原始片段
        print("Warning: All chunks were compressed to empty strings. Using original chunks.")
        filtered_chunks = [(chunk, 0.0) for chunk in retrieved_chunks]
    else:
        compressed_chunks, compression_ratios = zip(*filtered_chunks)
    
    # 从压缩片段生成上下文
    context = "\n\n---\n\n".join(compressed_chunks)
    
    # 基于压缩片段生成回复
    print("Generating response based on compressed chunks...")
    response = generate_response(query, context, model)
    
    # 准备结果字典
    result = {
        "query": query,
        "original_chunks": retrieved_chunks,
        "compressed_chunks": compressed_chunks,
        "compression_ratios": compression_ratios,
        "context_length_reduction": f"{sum(compression_ratios)/len(compression_ratios):.2f}%",
        "response": response
    }
    
    print("\n=== RESPONSE ===")
    print(response)
    
    return result

# %% [markdown]
# ## 比较有无压缩的RAG
# 让我们创建一个函数来比较标准RAG与我们增强压缩版本的RAG：

# %%
def standard_rag(pdf_path, query, k=10, model="qwen-plus"):
    """
    标准RAG（无压缩）。
    
    参数:
        pdf_path (str): PDF文档的路径
        query (str): 用户查询
        k (int): 要检索的块数
        model (str): 使用的LLM模型
        
    返回:
        dict: 包括查询、块和回复的结果字典
    """
    print("\n=== STANDARD RAG ===")
    print(f"Query: {query}")
    
    # 处理文档以提取文本、分块并创建嵌入
    vector_store = process_document(pdf_path)
    
    # 为查询创建嵌入
    query_embedding = create_embeddings(query)
    
    # 基于查询嵌入检索最相似的k个块
    print(f"Retrieving top {k} chunks...")
    results = vector_store.similarity_search(query_embedding, k=k)
    retrieved_chunks = [result["text"] for result in results]
    
    # 从检索到的块生成上下文
    context = "\n\n---\n\n".join(retrieved_chunks)
    
    # 基于检索到的块生成回复
    print("Generating response...")
    response = generate_response(query, context, model)
    
    # 准备结果字典
    result = {
        "query": query,
        "chunks": retrieved_chunks,
        "response": response
    }
    
    print("\n=== RESPONSE ===")
    print(response)
    
    return result

# %% [markdown]
# ## 评估我们的方法
# 现在，让我们实现一个函数来评估和比较回复：

# %%
def evaluate_responses(query, responses, reference_answer):
    """
    对多个回复与参考答案进行评估。
    
    参数:
        query (str): 用户查询
        responses (Dict[str, str]): 方法对应的回复字典
        reference_answer (str): 参考答案
        
    返回:
        str: 评估文本
    """
    # 定义系统提示以指导AI的行为进行评估
    system_prompt = """你是一位客观的RAG回复评估者。比较对同一查询的不同回复，
    并确定哪个回复最准确、全面且与查询最相关。"""
    
    # 创建用户提示，通过组合查询和参考答案生成
    user_prompt = f"""
    查询: {query}

    参考答案: {reference_answer}

    """
    
    # 将每个回复添加到提示中
    for method, response in responses.items():
        user_prompt += f"\n{method.capitalize()} 回复:\n{response}\n"
    
    # 在用户提示中添加评估标准
    user_prompt += """
    请根据以下标准评估这些回复：
    1. 与参考答案的事实准确性
    2. 全面性 - 回答查询的完整程度
    3. 简洁性 - 是否避免不相关的信息
    4. 整体质量

    请对回复进行从好到差的排名，并给出详细的解释。
    """
    
    # 使用OpenAI API生成评估回复
    evaluation_response = client.chat.completions.create(
        model="qwen-plus",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ],
        temperature=0
    )
    
    # 返回回复中的评估文本
    return evaluation_response.choices[0].message.content

# %%
def evaluate_compression(pdf_path, query, reference_answer=None, compression_types=["selective", "summary", "extraction"]):
    """
    比较不同的压缩技术与标准RAG方法。
    
    参数:
        pdf_path (str): PDF文档的路径
        query (str): 用户查询
        reference_answer (str): 可选的参考答案
        compression_types (List[str]): 要评估的压缩类型
        
    返回:
        dict: 评估结果
    """
    print("\n=== EVALUATING CONTEXTUAL COMPRESSION ===")
    print(f"Query: {query}")
    
    # 运行未压缩的标准RAG
    standard_result = standard_rag(pdf_path, query)
    
    # 存储不同压缩技术结果的字典
    compression_results = {}
    
    # 使用每种压缩技术运行RAG
    for comp_type in compression_types:
        print(f"\nTesting {comp_type} compression...")
        compression_results[comp_type] = rag_with_compression(pdf_path, query, compression_type=comp_type)
    
    # 收集回复以进行评估
    responses = {
        "standard": standard_result["response"]
    }
    for comp_type in compression_types:
        responses[comp_type] = compression_results[comp_type]["response"]
    
    # 如果提供参考答案，则评估回复
    if reference_answer:
        evaluation = evaluate_responses(query, responses, reference_answer)
        print("\n=== EVALUATION RESULTS ===")
        print(evaluation)
    else:
        evaluation = "No reference answer provided for evaluation."
    
    # 计算每种压缩类型的指标
    metrics = {}
    for comp_type in compression_types:
        metrics[comp_type] = {
            "avg_compression_ratio": f"{sum(compression_results[comp_type]['compression_ratios'])/len(compression_results[comp_type]['compression_ratios']):.2f}%",
            "total_context_length": len("\n\n".join(compression_results[comp_type]['compressed_chunks'])),
            "original_context_length": len("\n\n".join(standard_result['chunks']))
        }
    
    # 返回评估结果、回复和指标
    return {
        "query": query,
        "responses": responses,
        "evaluation": evaluation,
        "metrics": metrics,
        "standard_result": standard_result,
        "compression_results": compression_results
    }

# %% [markdown]
# ## 运行我们的完整系统（自定义查询）

# %%
# PDF 文档中包含 AI 伦理信息的路径  
pdf_path = "data/2024年AI行业报告.pdf"  

# 加载验证数据从一个JSON文件
with open('data/val.json') as f:
    data = json.load(f)

# 从验证数据中提取第一个查询
query = data[2]['question']

# 从验证数据中提取参考答案
reference_answer = data[2]['ideal_answer']


# 使用不同的压缩技术运行评估  
# 压缩类型：  
# - "selective"：保留关键细节，同时省略较不相关的内容  
# - "summary"：提供信息的简洁版本  
# - "extraction"：逐字提取文档中的相关内容  
results = evaluate_compression(  
    pdf_path=pdf_path,  
    query=query,  
    reference_answer=reference_answer,  
    compression_types=["selective", "summary", "extraction"]  
)
# Out:
# === EVALUATING CONTEXTUAL COMPRESSION ===
# Query: 中国政府对AI大模型发展有哪些支持政策？
#
# === STANDARD RAG ===
# Query: 中国政府对AI大模型发展有哪些支持政策？
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Retrieving top 10 chunks...
# Generating response...
#
# === RESPONSE ===
# 根据提供的上下文，中国政府对AI大模型发展的支持政策主要包括以下三个层面：
#
# 一、国家顶层设计与宏观战略部署
# - 国务院于2017年发布《新一代人工智能发展规划》，为人工智能发展提供长期战略指引；
# - 科技部等六部门于2022年印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》，落实上述规划；
# - 2024年《政府工作报告》明确提出开展“人工智能+”行动，将AI大模型作为赋能千行百业的关键抓手。
#
# 二、地方政府出台专项支持政策（截至2023年）
# 多地已发布聚焦AI大模型的专项政策，重点方向如下：
# - **北京**：
#   - 《北京市加快建设具有全球影响力的人工智能创新策源地实施方案（2023–2025年）》：支持突破分布式深度学习框架、大模型新型基础架构等基础平台技术；建设大模型算法及工具开源开放平台；组建全栈国产化人工智能创新联合体；研发全栈国产化的生成式大模型。
#   - 《北京市促进通用人工智能创新发展的若干措施》：加快人工智能公共算力中心建设（如海淀区、朝阳区），支撑千亿级参数大模型研发；开展大模型创新算法及关键技术研究（含高效并行训练、认知推理、指令学习、人类意图对齐、百亿参数模型端侧部署等）。
#
# - **上海**：
#   - 《上海市推动人工智能大模型创新发展若干措施（2023–2025年）》：实施大模型创新扶持计划，支持打造具有国际竞争力的大模型；鼓励形成“数据飞轮”加速模型迭代；对重大成果予以专项奖励；推进智能制造、生物医药、集成电路、科技金融、自动驾驶、数字政府等领域的示范应用场景建设。
#
# - **深圳**：
#   - 重点支持打造基于国内外芯片和算法的**开源通用大模型**；支持重点企业持续研发和迭代**商用通用大模型**。
#
# - **安徽**：
#   - 《安徽省人民政府关于印发打造通用人工智能产业创新和应用高地若干政策的通知》：对在皖落户的通用及行业大模型企业等，**优先匹配算力、数据、场景、基金、场地等要素资源**。
#
# - **成都**：
#   - 《成都市加快大模型创新应用推进人工智能产业高质量发展的若干措施》：着力推动大模型技术创新，重点研发和迭代CV大模型、NLP大模型、多模态大模型，以及医疗、金融、商务、交通等行业大模型。
#
# - **杭州**：
#   - 支持头部企业开展**多模态通用大模型关键技术攻关**；支持中小企业深耕垂直领域，做精**专用模型**。
#
# - **福建**：
#   - 《福建省促进人工智能产业发展十条措施》：以**普惠算力降低企业研发成本**，支撑自然语言、多模态认知等超大规模智能模型开发训练。
#
# - **广东**：
#   - 《广东省人民政府关于加快建设通用人工智能产业创新引领地的实施意见》：围绕基础架构、训练算法、调优对齐、推理部署等环节，研发**千亿级参数人工智能通用大模型**，形成自主可控的完整技术体系；聚焦智能经济、智能社会等场景，研发**多模态数据与知识深度融合的垂直领域大模型**。
#
# 三、政策共性支持方向（跨区域体现）
# - **强化算力基础设施供给**：建设人工智能公共算力中心、数字经济算力中心，提供规模化先进算力，支撑大模型训练；
# - **推动核心技术攻关**：覆盖模型架构、高效训练、指令微调、人类意图对齐、推理压缩、端侧部署等全链条技术；
# - **促进开源开放与生态构建**：建设开源开放平台，支持全栈国产化软硬件协同，推动大模型广泛开源；
# - **深化场景牵引与示范应用**：在政务、金融、医疗、制造、教育、交通、自动驾驶、机器人、数字政府等领域打造标杆性应用；
# - **优化要素资源配置**：优先保障算力、数据、场景、资金、场地等关键资源向大模型企业倾斜；
# - **推动国产替代与自主可控**：强调构建自主可控的技术体系和产业生态，发展全栈国产化大模型。
#
# 综上，中国政府通过“国家战略引导—部委统筹落实—地方精准施策”的三级政策体系，从顶层设计、技术研发、算力基建、开源生态、场景落地、要素保障、国产替代等多维度全面支持AI大模型产业发展。
#
# Testing selective compression...
#
# === RAG WITH CONTEXTUAL COMPRESSION ===
# Query: 中国政府对AI大模型发展有哪些支持政策？
# Compression type: selective
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Retrieving top 10 chunks...
# Compressing 10 chunks...
# Compressing chunk 1/10...
# Compressing chunk 2/10...
# Compressing chunk 3/10...
# Compressing chunk 4/10...
# Compressing chunk 5/10...
# Compressing chunk 6/10...
# Compressing chunk 7/10...
# Compressing chunk 8/10...
# Compressing chunk 9/10...
# Compressing chunk 10/10...
# Overall compression ratio: 77.14%
# Generating response based on compressed chunks...
#
# === RESPONSE ===
# 根据所提供的上下文，中国政府对AI大模型发展的支持政策包括以下几方面（均源自上下文明确提及的内容）：
#
# 一、国家层面政策
# - 2017年，国务院发布《新一代人工智能发展规划》，为人工智能发展提供顶层设计和战略指引（虽未专指大模型，但构成整体政策基础）。
# - 2022年，科技部等六部门印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》，落实规划，强调以场景驱动人工智能高水平应用。
# - 2024年《政府工作报告》明确提出开展“人工智能+”行动，作为推动大模型与实体经济深度融合的国家级行动部署。
#
# 二、地方政府专项政策（均已明确发布并具实操性）
# - **北京市**：
#   - 2023年5月发布《北京市加快建设具有全球影响力的人工智能创新策源地实施方案（2023–2025年）》，明确：
#     • 支持突破分布式高效深度学习框架、大模型新型基础架构等基础平台技术；
#     • 着力推动大模型相关技术创新；
#     • 构建高效协同的大模型技术产业生态；
#     • 建设大模型算法及工具开源开放平台；
#     • 组建全栈国产化人工智能创新联合体，研发全栈国产化的生成式大模型，构建自主可控的技术体系和产业生态。
#   - 同期发布《北京市促进通用人工智能创新发展的若干措施》，提出：
#     • 高效推动新增算力基础设施建设（如北京人工智能公共算力中心、北京数字经济算力中心），支撑千亿级参数大模型等研发；
#     • 开展大模型创新算法及关键技术研究，覆盖模型构建、训练、调优对齐、推理部署等全链条，包括高效并行训练、认知推理、指令学习、人类意图对齐、百亿参数模型端侧部署等。
#
# - **上海市**：
#   - 2023年10月印发《上海市推动人工智能大模型创新发展若干措施（2023–2025年）》，包括：
#     • 实施大模型创新扶持计划：支持引进高水平创新企业，支持打造具有国际竞争力的大模型，鼓励形成“数据飞轮”加速迭代，对重大成果予以专项奖励；
#     • 实施大模型示范应用推进计划：在智能制造、生物医药、集成电路、智能化教育教学、科技金融、设计创意、自动驾驶、机器人、数字政府等领域构建示范应用场景，打造标杆性大模型产品和服务。
#
# - **广东省**：
#   - 2023年11月出台《广东省人民政府关于加快建设通用人工智能产业创新引领地的实施意见》，明确：
#     • 围绕基础架构、训练算法、调优对齐、推理部署等环节，研发千亿级参数的通用大模型，形成自主可控的大模型完整技术体系；
#     • 聚焦智能经济、智能社会等场景，研发多模态数据与知识深度融合的垂直领域大模型，支撑多任务复杂行业应用。
#
# - **成都市**：
#   - 发布《成都市人工智能大模型创新应用推进人工智能产业高质量发展的若干措施》，着力推动大模型技术创新，重点研发迭代CV大模型、NLP大模型、多模态大模型，以及医疗、金融、商务、交通等行业大模型。
#
# - **福建省**：
#   - 2023年9月印发《福建省促进人工智能产业发展十条措施》，提出以普惠算力降低企业研发成本，支撑自然语言、多模态认知等超大规模智能模型的开发与训练。
#
# - **安徽省**：
#   - 2023年10月印发《打造通用人工智能产业创新和应用高地若干政策》，对在皖落户的通用及行业大模型企业、跨领域应用企业、新兴算力企业、安全人工智能企业等，优先匹配算力、数据、场景、基金、场地等要素资源。
#
# 三、政策导向与战略定位（贯穿全文）
# - 将AI大模型视为实现“新质生产力”的重要手段，支撑经济社会高质量发展；
# - 强调“场景牵引”，推动大模型在实体经济多领域落地应用；
# - 明确要求强化资源统筹、加强国产化与自主可控能力建设（如全栈国产化软硬件适配、自主可控技术体系）；
# - 将大模型发展纳入《国家创新驱动发展战略纲要》框架，服务于创新驱动和产业升级。
#
# 综上，上下文明确列出了国家“人工智能+”行动及多项省市级专项政策，涵盖顶层设计、算力基建、技术研发、生态构建、场景应用、要素保障、国产替代与国际竞争力培育等全方位支持举措。
#
# Testing summary compression...
#
# === RAG WITH CONTEXTUAL COMPRESSION ===
# Query: 中国政府对AI大模型发展有哪些支持政策？
# Compression type: summary
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Retrieving top 10 chunks...
# Compressing 10 chunks...
# Compressing chunk 1/10...
# Compressing chunk 2/10...
# Compressing chunk 3/10...
# Compressing chunk 4/10...
# Compressing chunk 5/10...
# Compressing chunk 6/10...
# Compressing chunk 7/10...
# Compressing chunk 8/10...
# Compressing chunk 9/10...
# Compressing chunk 10/10...
# Overall compression ratio: 82.71%
# Generating response based on compressed chunks...
#
# === RESPONSE ===
# 中国政府对AI大模型发展的支持政策涵盖国家与地方多层级、全链条的系统性部署，具体包括以下方面：
#
# 一、**国家战略与顶层设计**
# - 国务院2017年发布《新一代人工智能发展规划》，强化人工智能发展总体布局；
# - 2024年《政府工作报告》明确提出开展“人工智能+”行动，将AI大模型作为赋能千行百业的核心抓手；
# - 将人工智能上升为国家战略，明确AI大模型是发展新质生产力的关键技术，支撑产业智能化升级、催生新产业新模式新动能。
#
# 二、**国家部委协同推进**
# - 科技部等六部门2022年印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》，推动大模型在真实场景中落地应用；
# - 鼓励企业与科研机构联合攻关关键算法（如数据与知识深度学习、认知推理、可控内容生成），重点研发计算机视觉（CV）、自然语言处理（NLP）、多模态及医疗、金融、交通等垂直行业大模型。
#
# 三、**地方专项政策支持（覆盖北京、上海、深圳、杭州、成都、安徽、福建、广东等地）**
# - **北京市**：2023年发布《实施方案》和《若干措施》，支持大模型基础架构、训练技术、算法创新、开源平台建设及全栈国产化模型研发；加快公共算力中心建设，支撑千亿参数级大模型研发；
# - **上海市**：侧重提升国际竞争力；
# - **深圳市**：支持开源通用大模型研发与商用迭代；
# - **安徽省**：注重吸引优质资源集聚；
# - **成都市**：聚焦CV/NLP/多模态及行业大模型研发；
# - **杭州市**：鼓励头部企业攻关多模态通用模型，支持中小企业深耕垂直专用模型。
#
# 四、**技术研发与自主创新**
# - 推动构建覆盖基础架构、训练算法、调优对齐、推理部署的自主可控技术体系；
# - 支持千亿级参数通用大模型研发，发展多模态、知识深度融合的垂直领域大模型；
# - 鼓励大模型开源，降低开发门槛，助推产业生态创新；
# - 支持小型开发者调用大模型能力提升编程效率、加速应用落地。
#
# 五、**算力与基础设施保障**
# - 提供普惠算力服务，降低大模型研发成本；
# - 对落户企业优先匹配算力、数据、场景、基金和场地等资源；
# - 加快国产AI高性能芯片（如华为昇腾、寒武纪思元系列）研发与迭代，强化算力自主供给。
#
# 六、**生态构建与产业培育**
# - 推进开源平台建设、国产化替代、全栈技术体系构建；
# - 完善产业生态体系，将大模型作为发展新质生产力的重要引擎；
# - 实施大模型创新扶持计划，支持引进高水平企业，对重大成果给予专项奖励。
#
# 七、**示范应用与场景牵引**
# - 在智能制造、生物医药、自动驾驶、数字政府等领域打造标杆性应用场景；
# - 推动政务智能化：利用大模型实现自动化政策检索与比对、构建权威政策数据白名单与全量库、建设政策经验知识库、提供规范化生成与检查功能，提升政策制定效率与权威性；
# - 强调“场景牵引”，以真实需求驱动大模型高质量应用和实体经济转型。
#
# 综上，中国政府通过顶层设计、政策引导、资源倾斜、技术攻关、算力支撑、生态培育和场景落地等多维度举措，全面支持AI大模型的研发、创新、应用与产业化发展。
#
# Testing extraction compression...
#
# === RAG WITH CONTEXTUAL COMPRESSION ===
# Query: 中国政府对AI大模型发展有哪些支持政策？
# Compression type: extraction
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Retrieving top 10 chunks...
# Compressing 10 chunks...
# Compressing chunk 1/10...
# Compressing chunk 2/10...
# Compressing chunk 3/10...
# Compressing chunk 4/10...
# Compressing chunk 5/10...
# Compressing chunk 6/10...
# Compressing chunk 7/10...
# Compressing chunk 8/10...
# Compressing chunk 9/10...
# Compressing chunk 10/10...
# Overall compression ratio: 73.09%
# Generating response based on compressed chunks...
#
# === RESPONSE ===
# 根据提供的上下文，中国政府对AI大模型发展的支持政策涵盖国家层面顶层设计、专项行动、部委指导文件以及地方政府具体措施，具体如下：
#
# 一、国家层面宏观政策与战略部署
# 1. **《新一代人工智能发展规划》（2017年，国务院发布）**：作为我国人工智能发展的纲领性文件，为包括大模型在内的AI技术长期发展奠定顶层设计基础。
# 2. **《政府工作报告》（2024年）提出“人工智能+”行动**：将人工智能深度融入经济社会各领域，为大模型在行业应用提供国家级战略牵引和政策动能。
# 3. **《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》（2022年，科技部等六部门印发）**：强调以真实场景驱动AI技术落地，明确支持大模型在重点行业开展示范应用，推动技术与产业协同演进。
#
# 二、部委及中央部门配套举措
# - 上述指导意见是对《新一代人工智能发展规划》的细化落实，突出“场景创新—技术迭代—产业培育”闭环，为大模型提供应用验证、反馈优化和规模化推广的制度通道。
#
# 三、地方政府专项政策（覆盖北京、上海、深圳、杭州、成都、福建、安徽、广东等多地）
# 各地聚焦大模型技术研发、算力支撑、生态构建、行业应用与自主可控，出台具象化支持措施：
#
# ✅ **北京市**（2023年5月两项政策）：
# - 《北京市加快建设具有全球影响力的人工智能创新策源地实施方案（2023–2025年）》：
#   • 支持突破分布式高效深度学习框架、大模型新型基础架构等基础平台技术；
#   • 推动大模型相关技术创新，构建高效协同的技术产业生态；
#   • 建设大模型算法及工具开源开放平台，形成完整技术创新体系；
#   • 组建全栈国产化人工智能创新联合体，搭建国产软硬件训练/服务基础设施；
#   • 研发全栈国产化生成式大模型，推动自主可控技术体系和产业生态建设。
# - 《北京市促进通用人工智能创新发展的若干措施》：
#   • 高效推动新增算力基础设施建设（如海淀、朝阳的人工智能公共算力中心、数字经济算力中心），支撑千亿级参数大模型等前沿研发；
#   • 开展大模型创新算法及关键技术研究，覆盖模型构建、训练、调优对齐、推理部署全链条，包括高效并行训练、认知推理、指令学习、人类意图对齐、百亿参数模型端侧部署等。
#
# ✅ **上海市**（《上海市推动人工智能大模型创新发展若干措施（2023–2025年）》）：
# - 实施“大模型创新扶持计划”：支持引进高水平企业，鼓励打造具有国际竞争力的大模型；支持数据飞轮建设以加速模型迭代；对重大成果给予专项奖励；
# - 实施“大模型示范应用推进计划”：在智能制造、生物医药、集成电路、智能化教育教学、科技金融、设计创意、自动驾驶、机器人、数字政府等领域打造标杆性应用场景和产品。
#
# ✅ **广东省**（《关于加快建设通用人工智能产业创新引领地的实施意见》）：
# - 聚焦基础架构、训练算法、调优对齐、推理部署等环节，研发千亿级参数通用大模型，构建自主可控的完整技术体系；
# - 面向智能经济、智能社会等场景，研发多模态数据与知识深度融合的垂直领域大模型，支撑多任务复杂行业应用。
#
# ✅ **成都市**（《成都市人工智能大模型创新应用推进人工智能产业高质量发展的若干措施》）：
# - 着力推动大模型技术创新，重点研发迭代CV大模型、NLP大模型、多模态大模型，以及医疗、金融、商务、交通等行业大模型。
#
# ✅ **福建省**（《福建省促进人工智能产业发展十条措施》）：
# - 以普惠算力降低企业研发成本，支撑快速增长的算力需求，重点促进自然语言、多模态认知等超大规模智能模型的开发与训练。
#
# ✅ **安徽省**（《打造通用人工智能产业创新和应用高地若干政策》）：
# - 对在皖落户的通用及行业大模型企业、跨领域应用企业、新兴算力企业、安全人工智能企业等，优先匹配算力、数据、场景、基金、场地等要素资源。
#
# 四、政策导向共性特征（贯穿各级政策）
# - 强化**自主创新与自主可控**：强调全栈国产化、基础架构突破、国产软硬件适配；
# - 加强**算力基础设施保障**：建设公共算力中心，提升规模化先进算力供给能力；
# - 推动**技术—产业—应用闭环**：覆盖模型研发、训练调优、推理部署、开源生态、行业落地全链条；
# - 突出**场景驱动与示范牵引**：聚焦金融、医疗、政务、制造、交通、教育等高价值领域打造标杆应用；
# - 服务**新质生产力发展**：将大模型定位为催生高科技、高效能、高质量先进生产力的关键要素，支撑经济高质量发展和产业升级。
#
# 综上，中国政府已构建起“国家战略引领—部委统筹指导—地方精准施策”的多层次、全链条AI大模型支持政策体系。
#
# === EVALUATION RESULTS ===
# 我们依据四项评估标准（**事实准确性、全面性、简洁性、整体质量**），对四个回复（Standard、Selective、Summary、Extraction）进行严格比对，以**参考答案**为黄金标尺（“包括‘人工智能+’行动、支持通用与行业大模型研发、加快公共算力中心建设、推动算法和开源平台等一系列政策”），并结合查询本质——“中国政府对AI大模型发展有哪些支持政策？”——这一**聚焦政策要点、强调核心举措、无需过度展开历史沿革或理论阐释**的实用型政策咨询问题。
#
# ---
#
# ### ✅ **评估标准再明确**
# | 维度 | 定义 | 权重 | 关键判据 |
# |------|------|------|-----------|
# | **1. 事实准确性** | 所有陈述是否严格源自上下文，无编造、无夸大、无时间/主体/内容错位 | ★★★★☆ | 是否将未提及的政策（如“十四五规划”“信创工程”）混入；是否误读文件名称/发布时间/主体；是否将“支持方向”曲解为“已落地成果” |
# | **2. 全面性** | 是否覆盖参考答案全部4个核心要素（✅‘人工智能+’行动、✅通用与行业大模型研发、✅公共算力中心建设、✅算法与开源平台），并合理延伸关键支撑维度（如国产替代、场景应用、要素保障） | ★★★★☆ | 缺失任一核心要素即扣分；冗余堆砌非政策性内容（如技术原理、企业案例）不加分反减分 |
# | **3. 简洁性** | 是否紧扣“政策”本身，避免无关背景（如AI定义）、过程描述（如“如何训练”）、主观评价（如“意义重大”）、重复罗列（如多地政策仅列名不提炼共性） | ★★★☆☆ | 政策文本引用需精炼；地方政府举例应服务于说明“政策类型”，而非变成地方志汇编 |
# | **4. 整体质量** | 逻辑结构是否清晰（总-分？层级分明？）、语言是否专业简明、重点是否突出、可读性与实用性是否强（能否让政策研究者/企业申报者快速抓取要点） | ★★★★☆ | 是否形成“政策工具箱”式呈现（谁出台？什么政策？解决什么问题？）；是否混淆“政策”与“成效”“愿景”“技术路径” |
#
# > 🔍 **特别注意**：本任务是**RAG回复评估**，所有信息必须**严格基于提供的上下文**。任何超出上下文的推断（如“预计2025年建成XX中心”“已覆盖XX万企业”）均属事实错误。
#
# ---
#
# ## 🥇 **第一名：Extraction 回复**
# ### ✅ 得分：96/100
# **理由如下：**
#
# | 维度 | 表现 | 详细说明 |
# |------|------|----------|
# | **事实准确性** | ⭐⭐⭐⭐⭐（完美） | 所有政策名称、发文单位、年份、核心措辞（如“千亿级参数”“全栈国产化”“数据飞轮”“普惠算力”）均与上下文逐字匹配；未添加任何上下文未出现的信息（如未提“东数西算”“算力券”等外部概念）；对《新一代人工智能发展规划》的定位（“为包括大模型在内的AI技术奠定基础”）表述严谨，未越界宣称其“专为大模型制定”。 |
# | **全面性** | ⭐⭐⭐⭐⭐（全覆盖+精准延伸） | **完整覆盖参考答案4大要素**：<br>• “人工智能+”行动 → 单独列为国家层面第2项，加粗强调；<br>• 支持通用与行业大模型研发 → 贯穿北京（全栈国产化生成式大模型）、上海（国际竞争力大模型）、广东（千亿级通用+垂直领域）、成都（CV/NLP/多模态/医疗金融等行业模型）等全部案例；<br>• 加快公共算力中心建设 → 北京（海淀/朝阳算力中心）、福建（普惠算力）、安徽（优先匹配算力）三处明确点出；<br>• 推动算法和开源平台 → 北京（建设开源开放平台）、各地“算法研究”“指令学习”“人类意图对齐”等高频出现。<br>✅ 并提炼出**四大共性特征**（自主创新、算力保障、技术-产业-应用闭环、场景驱动），高度凝练且全部源自上下文。 |
# | **简洁性** | ⭐⭐⭐⭐☆（极佳） | 结构极度清晰：国家→部委→地方→共性，四级逻辑；地方政府用✅符号+政策名称+核心条款（bullet point），**每条均为不可删减的政策原文要点**，无一句空泛描述（如“高度重视”“大力推动”）；剔除所有修饰性副词（Standard中“高效推动”“着力推动”、Summary中“核心抓手”“关键引擎”等主观强化词）；政策动词统一为“支持”“建设”“研发”“实施”“推动”等客观表述。 |
# | **整体质量** | ⭐⭐⭐⭐⭐（典范级） | 是唯一实现**政策工具箱式输出**的回复：读者可直接按“政策类型—发布主体—核心条款”三元组提取信息；小标题使用“宏观政策与战略部署”“部委及中央部门配套举措”“地方政府专项政策”等精准分类；结尾“多层次、全链条”总结直击查询本质；语言冷静、专业、零冗余，完全符合政务/产业政策咨询场景需求。 |
#
# > 💡 **Extraction 的胜利关键**：它把RAG的本质做到了极致——**不是复述上下文，而是从上下文中精准萃取政策实体（Policy Entity），并结构化重组为可操作的知识图谱**。
#
# ---
#
# ## 🥈 **第二名：Selective 回复**
# ### ✅ 得分：89/100
# **理由如下：**
#
# | 维度 | 表现 | 详细说明 |
# |------|------|----------|
# | **事实准确性** | ⭐⭐⭐⭐⭐（优秀） | 所有政策名称、时间、主体、关键措辞均准确；对《新一代人工智能发展规划》的限定（“虽未专指大模型，但构成整体政策基础”）体现审慎；未添加任何虚构内容。 |
# | **全面性** | ⭐⭐⭐⭐☆（略逊于Extraction） | 同样覆盖参考答案4大要素，但：① “开源平台”在北京市部分明确，但其他地区未再强调，稍弱于Extraction的跨区域归纳；② “公共算力中心”在北京、福建、安徽均有，但Selective未像Extraction那样在“共性特征”中单列“算力基础设施保障”作为独立维度，而是融入各地方描述，结构性稍弱。 |
# | **简洁性** | ⭐⭐⭐⭐☆（良好） | 结构清晰（国家→地方→导向），删除了Standard中大量修饰语；但存在少量可优化冗余：如“同期发布《北京市促进……若干措施》”中“同期”非必要；“构建自主可控的技术体系和产业生态”在北京市部分重复出现两次。 |
# | **整体质量** | ⭐⭐⭐⭐☆（优秀） | 逻辑流畅，重点突出“上下文明确提及”的边界意识（开篇即声明“均源自上下文明确提及的内容”），增强可信度；结尾总结“全方位支持举措”准确有力。但相比Extraction，**政策归类颗粒度略粗**（如未将“场景牵引”单独升维为共性特征），略逊一筹。 |
#
# > ⚠️ **扣分点**：在“政策导向与战略定位”部分加入“将AI大模型视为实现‘新质生产力’的重要手段”——该表述**上下文未出现**（上下文仅在Summary中出现“新质生产力”，但Selective不应跨回复引用）。此为**轻微事实溢出**，故未给满分。
#
# ---
#
# ## 🥉 **第三名：Summary 回复**
# ### ✅ 得分：78/100
# **理由如下：**
#
# | 维度 | 表现 | 详细说明 |
# |------|------|----------|
# | **事实准确性** | ⭐⭐⭐☆☆（有风险） | 多处**引入上下文未明确的信息**：<br>• “将人工智能上升为国家战略”——上下文只提《新一代人工智能发展规划》《政府工作报告》，未使用“国家战略”定性；<br>• “鼓励小型开发者调用大模型能力提升编程效率”——上下文无此内容；<br>• “推进政务智能化：利用大模型实现自动化政策检索与比对……”——该段落为**典型幻觉**，上下文从未提及任何政务智能化具体功能；<br>• “加快国产AI高性能芯片（如华为昇腾、寒武纪思元系列）研发”——上下文未列任何芯片品牌。→ **存在实质性事实错误，严重损害可信度**。 |
# | **全面性** | ⭐⭐⭐⭐☆（覆盖全但掺水） | 4大核心要素全部覆盖，且维度最广（7个板块），但因混入虚假内容，**全面性价值被稀释**；例如“生态构建与产业培育”中“完善产业生态体系，将大模型作为发展新质生产力的重要引擎”——后半句为添加。 |
# | **简洁性** | ⭐⭐⭐☆☆（冗余明显） | 大量使用宣传性短语：“核心抓手”“关键引擎”“重要手段”“高质量发展”“催生新动能”等；小标题如“生态构建与产业培育”“示范应用与场景牵引”语义重叠；地方政府列举方式较松散（如“上海市：侧重提升国际竞争力”过于模糊，未列具体政策名称）。 |
# | **整体质量** | ⭐⭐⭐☆☆（结构尚可，内容存疑） | 七大部分看似系统，但因事实错误导致**整体可信度崩塌**；对政策实操者而言，无法区分哪些是真实政策、哪些是作者发挥，**实用性大幅降低**。 |
#
# > ❗ **致命伤**：在RAG评估中，**事实准确性具有一票否决权**。Summary的政务智能化细节、芯片品牌、新质生产力定性等，均属无依据编造，使其无法成为可靠政策参考。
#
# ---
#
# ## 🏴‍☠️ **第四名：Standard 回复**
# ### ✅ 得分：62/100
# **理由如下：**
#
# | 维度 | 表现 | 详细说明 |
# |------|------|----------|
# | **事实准确性** | ⭐⭐☆☆☆（严重问题） | **大规模事实性错误与过度解读**：<br>• 称“国务院于2017年发布《新一代人工智能发展规划》”——**正确，但上下文未说明其由国务院发布**（实际是国务院印发，但Standard擅自添加“国务院于……发布”，而上下文仅写“国务院发布”）；更严重的是：<br>• 将《关于加快场景创新……指导意见》的发文单位写作“科技部等六部门”，**但上下文未提“六部门”，只写“科技部等”** → 属于**无依据数字编造**；<br>• 多地政策时间全部标注为“截至2023年”，但上下文明确给出北京（2023年5月）、上海（2023年10月）等具体时间，Standard却模糊处理，**丧失关键时效性信息**；<br>• “深圳：重点支持打造基于国内外芯片和算法的开源通用大模型”——上下文原文为“支持打造基于国内外芯片和算法的**开源通用大模型**”，Standard擅自添加“重点”二字，属**程度夸大**。 |
# | **全面性** | ⭐⭐⭐⭐☆（要素齐全但失焦） | 4大要素全部覆盖，且地方政府列举最全（8地），但：① 过度展开技术细节（如“高效并行训练、认知推理、指令学习……”），这些是**技术研发内容，非政策本身**；② “三级政策体系”总结虽好，但被前面的事实错误拖累。 |
# | **简洁性** | ⭐⭐☆☆☆（严重冗余） | 最长回复；充斥主观强化词：“**高效推动**新增算力基础设施建设”“**着力推动**大模型技术创新”“**全面支持**……产业发展”；小标题如“强化算力基础设施供给”“推动核心技术攻关”等，**将政策目标（what）与执行动作（how）混为一谈**，违背“政策是什么”的查询本质。 |
# | **整体质量** | ⭐⭐☆☆☆（结构混乱，可信度最低） | 开篇即犯低级错误（“根据提供的上下文”却未核查上下文细节），暴露RAG基本功缺失；全文像一份未经核实的政策汇编草稿，**缺乏信息溯源意识与编辑校验**；对用户而言，阅读成本最高、风险最大。 |
#
# > ⚠️ **根本缺陷**：Standard 回复体现了典型的 **“RAG幻觉+信息过载+缺乏批判性验证”三重失败**。它把上下文当原料库，自行加工成“看起来很全”的报告，却忘了RAG的第一铁律：**忠实于源，止步于源**。
#
# ---
#
# ## 📊 最终排名与总结
#
# | 排名 | 回复名称 | 得分 | 核心优势 | 主要缺陷 |
# |------|-----------|------|------------|-------------|
# | **🥇 1st** | **Extraction** | **96** | ✅ 事实零误差 ✅ 四要素全覆盖 ✅ 结构即政策图谱 ✅ 语言绝对克制 | 无实质缺陷，教科书级RAG回复 |
# | **🥈 2nd** | **Selective** | **89** | ✅ 高度忠实上下文 ✅ 清晰标注信息边界 ✅ 逻辑清爽 | 少量跨文本引用（新质生产力）、共性提炼稍弱于Extraction |
# | **🥉 3rd** | **Summary** | **78** | ✅ 覆盖维度最广 ✅ 地方政策归类合理 | ❌ 多处事实编造（政务应用、芯片品牌、国家战略定性）→ **可信度硬伤** |
# | **❌ 4th** | **Standard** | **62** | ✅ 地方案例最全 ✅ 三级体系框架清晰 | ❌ 系统性事实错误（发文单位、时间、程度词） ❌ 技术细节冒充政策 ❌ 语言浮夸冗余 |
#
# ---
#
# ### ✅ 给开发者的终极建议：
# - **首选 Extraction**：它证明了RAG的最高境界——**不增不减、不评不议、只萃取、只结构化**。
# - **慎用 Summary & Standard**：它们警示我们——**信息越多，责任越大；结构越全，越需严守事实边界**。
# - **Selective 是安全折中**：适合需要强调“信息可验证性”的合规敏感场景（如政务咨询、企业申报）。
#
# 如需将 Extraction 回复进一步压缩为**一句话政策摘要**（适配PPT汇报/领导速览），我可立即为您生成。

# %% [markdown]
# ## 可视化压缩结果

# %%
def visualize_compression_results(evaluation_results):
    """
    可视化不同压缩技术的结果。

    参数:
        evaluation_results (Dict): evaluate_compression 函数返回的结果
    """
    # 从评估结果中提取查询和标准片段
    query = evaluation_results["query"]
    standard_chunks = evaluation_results["standard_result"]["chunks"]
    
    # 打印查询
    print(f"Query: {query}")
    print("\n" + "="*80 + "\n")
    
    # 获取一个示例片段以进行可视化（使用第一个片段）
    original_chunk = standard_chunks[0]
    
    # 遍历每种压缩类型并展示对比
    for comp_type in evaluation_results["compression_results"].keys():
        compressed_chunks = evaluation_results["compression_results"][comp_type]["compressed_chunks"]
        compression_ratios = evaluation_results["compression_results"][comp_type]["compression_ratios"]
        
        # 获取相应的压缩片段及其压缩比
        compressed_chunk = compressed_chunks[0]
        compression_ratio = compression_ratios[0]
        
        print(f"\n=== {comp_type.upper()} COMPRESSION EXAMPLE ===\n")
        
        # 显示原始片段（如果过长则截断）
        print("ORIGINAL CHUNK:")
        print("-" * 40)
        if len(original_chunk) > 800:
            print(original_chunk[:800] + "... [truncated]")
        else:
            print(original_chunk)
        print("-" * 40)
        print(f"Length: {len(original_chunk)} characters\n")
        
        # 显示压缩片段
        print("COMPRESSED CHUNK:")
        print("-" * 40)
        print(compressed_chunk)
        print("-" * 40)
        print(f"Length: {len(compressed_chunk)} characters")
        print(f"Compression ratio: {compression_ratio:.2f}%\n")
        
        # 显示该压缩类型的总体统计信息
        avg_ratio = sum(compression_ratios) / len(compression_ratios)
        print(f"Average compression across all chunks: {avg_ratio:.2f}%")
        print(f"Total context length reduction: {evaluation_results['metrics'][comp_type]['avg_compression_ratio']}")
        print("=" * 80)
    
    # 显示压缩技术的摘要表格
    print("\n=== COMPRESSION SUMMARY ===\n")
    print(f"{'Technique':<15} {'Avg Ratio':<15} {'Context Length':<15} {'Original Length':<15}")
    print("-" * 60)
    
    # 打印每种压缩类型的技术指标
    for comp_type, metrics in evaluation_results["metrics"].items():
        print(f"{comp_type:<15} {metrics['avg_compression_ratio']:<15} {metrics['total_context_length']:<15} {metrics['original_context_length']:<15}")

# %%
# 可视化压缩结果  
visualize_compression_results(results)
# Out:
# Query: 中国政府对AI大模型发展有哪些支持政策？
#
# ================================================================================
#
#
# === SELECTIVE COMPRESSION EXAMPLE ===
#
# ORIGINAL CHUNK:
# ----------------------------------------
# ..................31
# 3.3 高质量的训练数据集仍需扩展...................................................................32
# 3.4 大模型爆款应用尚未出现...........................................................................32
# 第四章天阔云高：中国AI 大模型产业趋势展望.................................................34
# 4.1 AI 云侧与端侧大模型满足不同需求，C 端用户将成为端侧的主要客群..........34
# 4.2 AI 大模型趋于通用化与专用化，垂直行业将是大模型的主战场..........34
# 4.3 AI 大模型将广泛开源，小型开发者可调用大模型能力提升开发效率..35
# 4.4 AI 高性能芯片不断升级，AI 大模型产业生态体系将不断完善.............36
# 结语............................................................................................................................37
# AI 大模型将加快新质生产力发展，助力我国经济社会高质量发展..............37
# 1/37
# 第一章扬帆起航：中国AI 大模型产业发展背景
# 1.1 中国AI 大模型产业发展政策驱动力
# 近年来，我国始终高度重视人工智能发展机遇和顶层设计，发布多项人工智
# 能支持政策，国务院于2017 年发布《新一代人工智能发展规划》。科技部等六
# 部门也于2022 年印发《关于加快场景创新以人工智能高水平应用促进经济高质
# 量发展... [truncated]
# ----------------------------------------
# Length: 1000 characters
#
# COMPRESSED CHUNK:
# ----------------------------------------
# 近年来，我国始终高度重视人工智能发展机遇和顶层设计，发布多项人工智能支持政策，国务院于2017 年发布《新一代人工智能发展规划》。科技部等六部门也于2022 年印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》对规划进行落实。2024 年《政府工作报告》中提出开展“人工智能+”行动。伴随人工智能领域中大模型技术的快速发展，我国各地方政府出台相关支持政策，加快大模型产业的持续发展。当前，北京、深圳、杭州、成都、福建、安徽、上海、广东等地均发布了关于AI 大模型的相关政策。具体来看，北京着力推动大模型相关技术创新，构建高效协同的大模型技术产业生态；上海强调打造具备国际竞争力的大模型。
# ----------------------------------------
# Length: 304 characters
# Compression ratio: 69.60%
#
# Average compression across all chunks: 76.04%
# Total context length reduction: 76.04%
# ================================================================================
#
# === SUMMARY COMPRESSION EXAMPLE ===
#
# ORIGINAL CHUNK:
# ----------------------------------------
# ..................31
# 3.3 高质量的训练数据集仍需扩展...................................................................32
# 3.4 大模型爆款应用尚未出现...........................................................................32
# 第四章天阔云高：中国AI 大模型产业趋势展望.................................................34
# 4.1 AI 云侧与端侧大模型满足不同需求，C 端用户将成为端侧的主要客群..........34
# 4.2 AI 大模型趋于通用化与专用化，垂直行业将是大模型的主战场..........34
# 4.3 AI 大模型将广泛开源，小型开发者可调用大模型能力提升开发效率..35
# 4.4 AI 高性能芯片不断升级，AI 大模型产业生态体系将不断完善.............36
# 结语............................................................................................................................37
# AI 大模型将加快新质生产力发展，助力我国经济社会高质量发展..............37
# 1/37
# 第一章扬帆起航：中国AI 大模型产业发展背景
# 1.1 中国AI 大模型产业发展政策驱动力
# 近年来，我国始终高度重视人工智能发展机遇和顶层设计，发布多项人工智
# 能支持政策，国务院于2017 年发布《新一代人工智能发展规划》。科技部等六
# 部门也于2022 年印发《关于加快场景创新以人工智能高水平应用促进经济高质
# 量发展... [truncated]
# ----------------------------------------
# Length: 1000 characters
#
# COMPRESSED CHUNK:
# ----------------------------------------
# 中国政府对AI大模型发展的支持政策包括：
# - 国务院2017年发布《新一代人工智能发展规划》，强化顶层设计；
# - 科技部等六部门2022年印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》，推动政策落地；
# - 2024年《政府工作报告》提出开展“人工智能+”行动；
# - 北京、上海、深圳、杭州、成都、福建、安徽、广东等地出台地方性AI大模型支持政策，聚焦技术创新、生态构建、国际竞争力提升等方向。
# ----------------------------------------
# Length: 217 characters
# Compression ratio: 78.30%
#
# Average compression across all chunks: 82.01%
# Total context length reduction: 82.01%
# ================================================================================
#
# === EXTRACTION COMPRESSION EXAMPLE ===
#
# ORIGINAL CHUNK:
# ----------------------------------------
# ..................31
# 3.3 高质量的训练数据集仍需扩展...................................................................32
# 3.4 大模型爆款应用尚未出现...........................................................................32
# 第四章天阔云高：中国AI 大模型产业趋势展望.................................................34
# 4.1 AI 云侧与端侧大模型满足不同需求，C 端用户将成为端侧的主要客群..........34
# 4.2 AI 大模型趋于通用化与专用化，垂直行业将是大模型的主战场..........34
# 4.3 AI 大模型将广泛开源，小型开发者可调用大模型能力提升开发效率..35
# 4.4 AI 高性能芯片不断升级，AI 大模型产业生态体系将不断完善.............36
# 结语............................................................................................................................37
# AI 大模型将加快新质生产力发展，助力我国经济社会高质量发展..............37
# 1/37
# 第一章扬帆起航：中国AI 大模型产业发展背景
# 1.1 中国AI 大模型产业发展政策驱动力
# 近年来，我国始终高度重视人工智能发展机遇和顶层设计，发布多项人工智
# 能支持政策，国务院于2017 年发布《新一代人工智能发展规划》。科技部等六
# 部门也于2022 年印发《关于加快场景创新以人工智能高水平应用促进经济高质
# 量发展... [truncated]
# ----------------------------------------
# Length: 1000 characters
#
# COMPRESSED CHUNK:
# ----------------------------------------
# 近年来，我国始终高度重视人工智能发展机遇和顶层设计，发布多项人工智能支持政策，国务院于2017 年发布《新一代人工智能发展规划》。科技部等六部门也于2022 年印发《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》对规划进行落实。2024 年《政府工作报告》中提出开展“人工智能+”行动。伴随人工智能领域中大模型技术的快速发展，我国各地方政府出台相关支持政策，加快大模型产业的持续发展。当前，北京、深圳、杭州、成都、福建、安徽、上海、广东等地均发布了关于AI 大模型的相关政策。具体来看，北京着力推动大模型相关技术创新，构建高效协同的大模型技术产业生态；上海强调打造具备国际竞争力的大模型；深
# ----------------------------------------
# Length: 305 characters
# Compression ratio: 69.50%
#
# Average compression across all chunks: 72.37%
# Total context length reduction: 72.37%
# ================================================================================
#
# === COMPRESSION SUMMARY ===
#
# Technique       Avg Ratio       Context Length  Original Length
# ------------------------------------------------------------
# selective       76.04%          2205            9586
# summary         82.01%          1672            9586
# extraction      72.37%          2593            9586

# %% [markdown]
# # 什么时候进行上下文压缩呢？

# %% [markdown]
# ## RAG 中的上下文压缩——何时做、怎么做
#
# 在 Retrieval-Augmented Generation (RAG) 系统里，“上下文压缩”（Context Compression）指对检索回来的原始资料进行删减、摘要或重写，以更少的 token 携带同等或更高的信息密度，便于下游大模型消费。是否需要做压缩，本质上取决于**两条硬约束**和**两类性能目标**：
#
# | 决策维度        | 典型触发条件                                             | 说明                        |
# | ----------- | -------------------------------------------------- | ------------------------- |
# | **模型与接口限制** | - 超过 LLM 单次最大输入 tokens<br>- API 调用成本过高（按 token 计费） | 无法直接塞进 prompt 或成本不划算时，先压缩 |
# | **场景性能目标**  | - 对时延要求严苛<br>- 需多轮检索/链式思考，累积上下文不断膨胀                | 压缩能减少 I/O 量和推理时间          |
#
# ---
#
# ### 1. 检索 **后**、生成 **前**：最常见的压缩位点
#
# ```mermaid
# graph LR
# 用户查询 -->|搜索| 检索器
# 检索器 -->|返回 n 条文档| 文档集
# 文档集 -->|摘要/抽取| ⚡压缩器
# ⚡压缩器 -->|tokens↓| LLM
# ```
#
# * **何时触发**
#
#   * `n×chunk_size` 已接近 / 超出 入口 token 上限
#   * 文档冗余度高：多条资料内容相似或段落重复
# * **常用方法**
#
#   * 逐条摘要（map-reduce summarization）
#   * 关键句抽取（sentence scoring + top-k）
#   * Question-focused compression：只保留能回答当前 query 的句子
# * **示例**
#
#   * 用户问「Explain the plot of *War and Peace* in Chinese」，检索器返 20 万字全文 → 压缩器产出 800 字情节摘要，再交给 LLM 翻译与润色。
#
# ---
#
# ### 2. 检索 **前**：离线文档预压缩
#
# > 适用于**知识库规模极大**且**文档格式杂乱**的场景（企业维基、法律条款、医学文献）。
#
# * **何时触发**
#
#   1. **内存 / 磁盘成本**：将数 TB 的原文直接切 chunk 存向量库不现实。
#   2. **检索精度瓶颈**：冗余句子稀释向量语义，召回错匹配。
# * **做法**
#
#   * 离线抽取文档“精华摘要”或 topic-level embedding；
#   * 只把“压缩后的版本”入库；
#   * 真正需要细节时再二次检索原文（two-stage retrieval）。
# * **示例**
#
#   * 法律搜索：先把每份判决书压缩成「案由＋争议焦点＋裁判要旨」三段；查询时按这三段 embedding 检索，点进详情再拉原文。
#
# ---
#
# ### 3. 交互 (chain-of-thought) **中途**：链式思考上下文滚动压缩
#
# 在复杂的 Agent / Toolformer 流程里，模型要把**历史推理轨迹**连同**外部检索结果**一起馈入下一步调用，很快就爆 token。
#
# * **触发信号**
#
#   * 历史对话窗口 > 4 K tokens 或下一步工具调用前检测到将溢出。
# * **压缩策略**
#
#   * 把旧推理步骤用“Self-Refine”总结成决策要点；
#   * 只保留必要参数与最终结论，丢弃细节。
# * **示例**
#
#   ```pseudo
#   # Agent 的 memory buffer
#   1. 步骤1：列举 10 种假设 … → 已凝结为两句话
#   2. 步骤2：检索支持资料 … → 爬取页面标题与引用即可
#   3. 步骤3：给出最终答案 … → 保留完整
#   ```
#
# ---
#
# ## 小结：判断流程
#
# ```text
# IF (输入 token 预计超限 OR 成本/延迟过高) THEN
#     压缩上下文
#     ├─ IF 在检索后 -> 聚合/摘要当前文档块
#     ├─ ELSE IF 离线数据准备阶段 -> 预压缩存库
#     └─ ELSE IF 多轮推理中 -> 对历史对话 & 中间结果滚动摘要
# ELSE
#     直接拼接 prompt
# ```
#
# 在实践中，可以用 **启发式阈值**（如 `total_tokens > 0.8 * max_context`） 或 **自适应调度器**（监控 QPS、Latency、费用）来自动决定是否启动压缩，让 RAG 在质量和资源之间动态平衡。

# %% [markdown]
# 这笔记为你梳理了 RAG 上下文压缩中关于**延迟、完整性与底层推理优化**的核心逻辑。
#
# ---
#
# # 📝 RAG 上下文压缩与推理性能优化笔记
#
# ## 核心矛盾
# 在 RAG（检索增强生成）场景中，检索到的数据量往往会超过 LLM 的上下文窗口（Context Window）。解决这一问题的方法是**上下文压缩**，但随之带来两个核心挑战：
# 1.  **延迟（Latency）：** 压缩过程本身耗时，可能导致用户等待过久。
# 2.  **完整性（Integrity）：** 如果不完全处理完就交给模型，是否会导致语义断层？
#
# ---
#
# ## 一、 工业界处理压缩延迟的四种策略
#
# 为了平衡“精度”与“速度”，业界并不单一依赖长文本压缩，而是采用分层治理：
#
# * **Reranking（重排）替代全量压缩：** 先通过快而精的小模型（如 BGE-Reranker）将 Top 50 检索结果精选为 Top 5，直接剔除无关块。这是目前最主流、性价比最高的方法。
# * **启发式清理：** 利用正则、停用词过滤等“零耗时”手段先行精简 Token。
# * **专门的压缩模型：** 使用如 **LLMLingua** 这种基于信息熵的模型，它比直接叫 LLM 总结要快得多，且能保持语义完整。
# * **异步化与并行处理：** 将压缩任务拆分，利用 GPU 并发能力同时处理多个数据块。
#
# ---
#
# ## 二、 关于“语义完整性”的质疑与深度解析
#
# **质疑：** 如果为了降低延迟，在压缩未完成时就喂给 LLM，模型拿到的上下文是不完整的，这是否会导致生成错误？
#
# **深度解答：**
# 绝对不能在上下文不完整的情况下让模型开始**生成（Decoding）**。所谓的“提前介入”是指在**计算层面的并行**，而非逻辑层面的抢跑。
#
# 1.  **掩盖的是计算开销：** 优化目标是让“压缩时间”与“模型预计算（Prefill）时间”重叠。
# 2.  **因果顺序：** 由于主流 LLM 是 Decoder-only 架构，前面的 Token 无法看到后面的 Token。因此，按顺序预先计算前文的物理特征（KV Cache）是完全合法的，不会影响最终结果。
#
# ---
#
# ## 三、 现代推理引擎的黑科技：分块预填充 (Chunked Prefill)
#
# 这是解决长文本 RAG 延迟的核心技术，由 vLLM、TensorRT-LLM 等框架实现。
#
# ### 1. 什么是 Prefill（预填充）？
# * **阶段一：Prefill。** 处理 Prompt，一次性计算所有输入 Token 的 **KV Cache**。这是计算密集型阶段。
# * **阶段二：Decoding。** 逐个吐字。这是访存密集型阶段。
#
# ### 2. 如何实现“边压缩边预填充”？
# 通过 **Chunked Prefill** 技术，推理引擎不再死等全部文本到齐：
#
# * **流水线化（Pipelining）：**
#     * 压缩算法处理完第一段文本 $\rightarrow$ 立即送入 GPU 计算 KV Cache。
#     * 当压缩算法处理第二段时，GPU 已经在并行处理第一段的计算。
# * **PagedAttention（分块注意力）：**
#     * 像操作系统管理内存页一样，将计算出的 KV Cache 存储在非连续的显存块中。
#     * 即使压缩后的文本块是零碎到达的，引擎也能通过“页表”将其逻辑串联。
#
# ### 3. 最终效果
# 用户感知的 **TTFT（首字延迟）** 被大幅压缩：
# $$\text{感知延迟} \approx \text{最后一块文本的压缩时间} + \text{最后一块文本的 Prefill 时间}$$
# 而不是“总压缩时间 + 总 Prefill 时间”。
#
# ---
#
# ## 四、 总结：业界的“标准动作”
#
# 1.  **先过滤（Rerank）：** 减小进入压缩环节的基数。
# 2.  **再压缩（Compress）：** 使用轻量级算法顺序产出压缩文本。
# 3.  **流式预填（Chunked Prefill）：** 压缩出一块，GPU 就算一块。
# 4.  **最后生成（Generate）：** 待所有上下文的 KV Cache 全部到位，模型瞬间转入生成模式，吐出第一个字。
#
# **结论：** 现代架构通过**计算与通信的重叠**，在保证模型“读完整个上下文”的前提下，极大降低了用户的等待感。
