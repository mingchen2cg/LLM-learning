# %% [markdown]
# # Reranking for Enhanced RAG Systems
#
# 本笔记本实现了一种reranking（重排序）技术，以提高RAG系统中的检索质量。Reranking作为初始检索后的第二道过滤步骤，确保使用最相关的内容进行回复生成。
#
# ## Reranking 的关键概念
#
# 1. **初始检索**：第一轮使用基本的相似性搜索（准确性较低但速度较快）
# 2. **文档评分**：评估每个检索到的文档与查询的相关性
# 3. **重新排序**：根据相关性分数对文档进行排序
# 4. **选择**：仅使用最相关的文档进行回复生成

# %% [markdown]
# ![image.png](attachment:d8f37aa4-8fbe-42bd-9fe6-84505c3002b5.png)

# %% [markdown]
# ### 此notebook基于规则rerank，基于rerank_model的rerank解释见下面链接
# https://oxpzcwcjtbk.feishu.cn/docx/JDoXdgTUtoORb3xcdj5ccmOsnae

# %% [markdown]
# ## 环境设置
# 我们首先导入必要的库。

# %%
import fitz  # PyMuPDF库，用于处理PDF文件
import os  # 操作系统相关功能，如文件路径管理
import numpy as np  # NumPy库，用于数值计算
import json  # JSON数据处理
from openai import OpenAI  # OpenAI API客户端
import re  # 正则表达式模块，用于文本匹配和处理
import dashscope
# Out:
# /t9k/mnt/.conda/envs/llm/lib/python3.10/site-packages/requests/__init__.py:109: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.4.3)/charset_normalizer (3.4.6) doesn't match a supported version!
#   warnings.warn(

# %% [markdown]
# ## 从PDF文件中提取文本
# 为了实现RAG（Retrieval-Augmented Generation，检索增强生成），我们首先需要一个文本数据源。在此情况下，我们使用PyMuPDF库从PDF文件中提取文本。

# %%
def extract_text_from_pdf(pdf_path):
    """
    从PDF文件中提取文本并打印前`num_chars`个字符。

    参数:
    pdf_path (str): PDF文件的路径。

    返回:
    str: 从PDF中提取的文本。
    """
    # 打开PDF文件
    mypdf = fitz.open(pdf_path)
    all_text = ""  # 初始化一个空字符串用于存储提取的文本

    # 遍历PDF中的每一页
    for page_num in range(mypdf.page_count):
        page = mypdf[page_num]  # 获取页面
        text = page.get_text("text")  # 从页面提取文本
        all_text += text  # 将提取的文本追加到all_text字符串中

    return all_text  # 返回提取的文本

# %% [markdown]
# ## 提取文本的分块
# 在提取文本之后，我们将其划分为更小的、相互重叠的部分，以提高检索准确性。

# %%
def chunk_text(text, n, overlap):
    """
    将给定的文本分割成每段包含 n 个字符且具有 overlap 的片段。

    参数:
    text (str): 需要分割的文本。
    n (int): 每个片段的字符数。
    overlap (int): 每两个片段之间的重叠字符数。

    返回:
    List[str]: 一个包含文本片段的列表。
    """
    chunks = []  # 初始化一个空列表用于存储片段
    
    # 使用 (n - overlap) 的步长遍历文本
    for i in range(0, len(text), n - overlap):
        # 将从索引 i 到 i + n 的文本片段添加到 chunks 列表中
        chunks.append(text[i:i + n])

    return chunks  # 返回包含文本片段的列表

# %% [markdown]
# ## 初始化OpenAI API客户端
# 我们初始化OpenAI客户端以生成嵌入向量和回复。

# %%
from dotenv import load_dotenv
import os

load_dotenv()  # 加载.env文件
api_key = os.getenv("DASHSCOPE_API_KEY")  # 读取密钥
base_url = os.getenv("base_url")
# print(api_key)
# 初始化 OpenAI 客户端，设置基础 URL 和 API 密钥
client = OpenAI(
    base_url=base_url,
    api_key=api_key,  # 从环境变量中获取 API 密钥
)

# %% [markdown]
# ## 构建一个简单的向量存储系统
# 为了展示重新排名（reranking）如何与检索（retrieval）集成，让我们实现一个简单的向量存储系统。

# %%
class SimpleVectorStore:
    """
    一个使用NumPy实现的简单向量存储。
    """
    def __init__(self):
        """
        初始化向量存储。
        """
        self.vectors = []  # 存储嵌入向量的列表
        self.texts = []  # 存储原始文本的列表
        self.metadata = []  # 存储每个文本元数据的列表
    
    def add_item(self, text, embedding, metadata=None):
        """
        向向量存储中添加一个项目。

        参数:
        text (str): 原始文本。
        embedding (List[float]): 嵌入向量。
        metadata (dict, 可选): 额外的元数据。
        """
        self.vectors.append(np.array(embedding))  # 将嵌入转换为numpy数组并添加到向量列表中
        self.texts.append(text)  # 将原始文本添加到文本列表中
        self.metadata.append(metadata or {})  # 添加元数据到元数据列表中，如果为None则使用空字典
    
    def similarity_search(self, query_embedding, k=5):
        """
        查找与查询嵌入最相似的项目。

        参数:
        query_embedding (List[float]): 查询嵌入向量。
        k (int): 返回结果的数量。

        返回:
        List[Dict]: 最相似的前k个项目及其文本和元数据。
        """
        if not self.vectors:
            return []  # 如果没有存储向量，则返回空列表
        
        # 将查询嵌入转换为numpy数组
        query_vector = np.array(query_embedding)
        
        # 使用余弦相似度计算相似性
        similarities = []
        for i, vector in enumerate(self.vectors):
            # 计算查询向量和存储向量之间的余弦相似度
            similarity = np.dot(query_vector, vector) / (np.linalg.norm(query_vector) * np.linalg.norm(vector))
            similarities.append((i, similarity))  # 将索引和相似度分数添加到列表中
        
        # 按相似度降序排序
        similarities.sort(key=lambda x: x[1], reverse=True)
        
        # 返回前k个结果
        results = []
        for i in range(min(k, len(similarities))):
            idx, score = similarities[i]
            results.append({
                "text": self.texts[idx],  # 添加对应的文本
                "metadata": self.metadata[idx],  # 添加对应的元数据
                "similarity": score  # 添加相似度分数
            })
        
        return results  # 返回最相似的前k个项目列表

# %% [markdown]
# ## 创建嵌入（Embeddings）

# %%
def create_embeddings(text, model="text-embedding-v4"):
    """
    使用指定的模型为给定文本创建嵌入。

    参数:
    text (str): 需要创建嵌入的输入文本。
    model (str): 用于创建嵌入的模型。

    返回:
    List[float]: 嵌入向量。
    """
    # 1. 统一转换为列表进行批处理计算
    input_text = [text] if isinstance(text, str) else text

    max_batch_size = 10
    all_embeddings = []

    # 2. 按照每 10 个一组进行分批请求，避免触发 API 限制
    for i in range(0, len(input_text), max_batch_size):
        batch = input_text[i : i + max_batch_size]
        response = client.embeddings.create(model=model, input=batch)
        # 将当前批次的结果提取并合并
        all_embeddings.extend([item.embedding for item in response.data])

    # 3. 严格遵循原有的返回逻辑：
    # 如果输入是字符串，则返回第一个嵌入向量 (List[float])
    if isinstance(text, str):
        return all_embeddings[0]

    # 否则，返回所有嵌入向量的列表 (List[List[float]])
    return all_embeddings

# %% [markdown]
# ## 文档处理管道
# 既然我们已经定义了必要的函数和类，现在可以继续定义文档处理管道。

# %%
def process_document(pdf_path, chunk_size=1000, chunk_overlap=200):
    """
    处理文档以供RAG使用。

    参数:
    pdf_path (str): PDF文件的路径。
    chunk_size (int): 每个块的字符数大小。
    chunk_overlap (int): 块之间的重叠字符数。

    返回:
    SimpleVectorStore: 包含文档块及其嵌入的向量存储。
    """
    # 从PDF文件中提取文本
    print("Extracting text from PDF...")
    extracted_text = extract_text_from_pdf(pdf_path)
    
    # 将提取的文本分块
    print("Chunking text...")
    chunks = chunk_text(extracted_text, chunk_size, chunk_overlap)
    print(f"Created {len(chunks)} text chunks")
    
    # 为文本块创建嵌入
    print("Creating embeddings for chunks...")
    chunk_embeddings = create_embeddings(chunks)
    
    # 初始化一个简单的向量存储
    store = SimpleVectorStore()
    
    # 将每个块及其嵌入添加到向量存储中
    for i, (chunk, embedding) in enumerate(zip(chunks, chunk_embeddings)):
        store.add_item(
            text=chunk,
            embedding=embedding,
            metadata={"index": i, "source": pdf_path}
        )
    
    print(f"Added {len(chunks)} chunks to the vector store")
    return store

# %% [markdown]
# ## 基于LLM的重排序实现
# 让我们使用OpenAI API来实现基于LLM的重排序功能。

# %%
def rerank_with_llm(query, results, top_n=3, model="qwen-plus"):
    """
    使用LLM进行相关性评分来重新排序搜索结果。
    
    参数:
        query (str): 用户查询
        results (List[Dict]): 初始搜索结果
        top_n (int): 重新排序后返回的结果数量
        model (str): 用于评分的模型
        
    返回:
        List[Dict]: 重新排序后的结果
    """
    print(f"Reranking {len(results)} documents...")  # 打印将要重新排序的文档数量
    
    scored_results = []  # 初始化一个空列表来存储评分结果
    
    # 定义LLM的系统提示
    system_prompt = """你是一名擅长评估文档与查询相关性的专家。
你的任务是根据文档对查询的回答程度，对文档进行0到10分的打分。

评分标准：
- 0-2分：文档与查询完全无关
- 3-5分：文档包含部分相关信息，但未能直接回答查询
- 6-8分：文档相关，能够部分回答查询
- 9-10分：文档高度相关，能够直接回答查询

你必须只回复一个0到10之间的整数分数，不要包含任何其他文本。"""
    
    # 遍历每个结果
    for i, result in enumerate(results):
        # 每隔5个文档显示一次进度
        if i % 5 == 0:
            print(f"Scoring document {i+1}/{len(results)}...")
        
        # 定义LLM的用户提示
        user_prompt = f"""查询：{query}

        文档内容：
        {result['text']}

        请根据上述查询，对该文档与查询的相关性进行0到10分的打分："""
        
        # 获取LLM的回复
        response = client.chat.completions.create(
            model=model,
            temperature=0,
            messages=[
                {"role": "system", "content": system_prompt},
                {"role": "user", "content": user_prompt}
            ]
        )
        
        # 从LLM回复中提取分数
        score_text = response.choices[0].message.content.strip()
        
        # 使用正则表达式提取数值分数
        score_match = re.search(r'\b(10|[0-9])\b', score_text)
        if score_match:
            score = float(score_match.group(1))
        else:
            # 如果分数提取失败，则使用相似度分数作为回退方案
            print(f"Warning: Could not extract score from response: '{score_text}', using similarity score instead")
            score = result["similarity"] * 10
        
        # 将评分结果追加到列表中
        scored_results.append({
            "text": result["text"],
            "metadata": result["metadata"],
            "similarity": result["similarity"],
            "relevance_score": score
        })
    
    # 按相关性分数降序对结果进行排序
    reranked_results = sorted(scored_results, key=lambda x: x["relevance_score"], reverse=True)
    
    # 返回前top_n个结果
    return reranked_results[:top_n]

# %% [markdown]
# ## 简单基于关键词的重新排序

# %%
#pip install jieba

import jieba

def rerank_with_keywords(query, results, top_n=3):
    """
    基于中文关键词分词和位置的简单重排序方法。
    
    参数:
        query (str): 用户查询（中文）
        results (List[Dict]): 初始搜索结果
        top_n (int): 重排序后返回的结果数量
        
    返回:
        List[Dict]: 重排序后的结果
    """
    # 用jieba对查询进行分词，过滤掉长度为1的词（可根据实际需求调整）
    keywords = [word for word in jieba.lcut(query) if len(word) > 1]
    
    scored_results = []  # 初始化一个列表用于存储评分结果
    
    for result in results:
        document_text = result["text"]
        
        # 基础分数从向量相似度开始
        base_score = result["similarity"] * 0.5
        
        # 初始化关键词分数
        keyword_score = 0
        for keyword in keywords:
            if keyword in document_text:
                # 每找到一个关键词就加分
                keyword_score += 0.1
                
                # 如果关键词出现在开头附近，则加更多分
                first_position = document_text.find(keyword)
                if 0 <= first_position < len(document_text) / 4:  # 在文本的前四分之一部分
                    keyword_score += 0.1
                
                # 根据关键词频率加分
                frequency = document_text.count(keyword)
                keyword_score += min(0.05 * frequency, 0.2)  # 最多加到 0.2
        
        # 通过结合基础分数和关键词分数计算最终分数
        final_score = base_score + keyword_score
        
        # 将评分结果追加到列表中
        scored_results.append({
            "text": result["text"],
            "metadata": result["metadata"],
            "similarity": result["similarity"],
            "relevance_score": final_score
        })
    
    # 按最终相关性分数降序对结果进行排序
    reranked_results = sorted(scored_results, key=lambda x: x["relevance_score"], reverse=True)
    
    # 返回 top_n 个结果
    return reranked_results[:top_n]
# Out:
# /t9k/mnt/.conda/envs/llm/lib/python3.10/site-packages/jieba/_compat.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %% [markdown]
# # 基于rerank模型的重排
#
# https://bailian.console.aliyun.com/?spm=5176.29619931.nav-v2-dropdown-menu-0.d_main_0_4.74cd521cGo9V3Y&tab=api&scm=20140722.M_10811567._.V_1#/api/?type=model&url=https%3A%2F%2Fhelp.aliyun.com%2Fdocument_detail%2F2780056.html

# %%
def qwen_model_rerank(query, documents, top_n=5, model="qwen-rerank"):
    """
    使用专门的 qwen-rerank 模型进行文本重排序
    """
    # 提取文档文本内容用于重排
    # 假设 documents 的格式为 list of langchain Document objects
    docs_text = [doc.page_content for doc in documents]

    # 调用 DashScope 的重排序接口
    response = dashscope.TextReRank.call(
        model=model,  # 如果有 qwen3-rerank 可替换为此处
        query=query,
        documents=docs_text,
        top_n=top_n,
        return_documents=True,
    )

    reranked_docs = []
    if response.status_code == 200:
        # 按照返回的高相关性顺序，重新映射回原文档对象
        for item in response.output.results:
            original_index = item.document.index
            reranked_docs.append(documents[original_index])
    else:
        print(
            f"Rerank API 调用失败: Code {response.status_code}, Message: {response.message}"
        )

    return reranked_docs

# %% [markdown]
# ## 回复生成

# %%
def generate_response(query, context, model="qwen-plus"):
    """
    根据查询和上下文生成回复（中文版本）。
    
    参数:
        query (str): 用户查询
        context (str): 检索到的上下文
        model (str): 用于生成回复的模型
        
    返回:
        str: 生成的回复
    """
    # 中文系统提示
    system_prompt = (
        "你是一名乐于助人的AI助手，只能根据提供的上下文内容回答用户的问题。"
        "如果在上下文中找不到答案，请明确说明“我没有足够的信息来回答该问题”。"
    )
    
    # 中文用户提示
    user_prompt = f"""
上下文内容：
{context}

问题：{query}

请仅根据上述上下文内容，给出全面、详细的回答。
"""

    # 使用指定的模型生成回复
    response = client.chat.completions.create(
        model=model,
        temperature=0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    
    # 返回生成的回复内容
    return response.choices[0].message.content

# %% [markdown]
# ## 完整的RAG管道与重排序
# 到目前为止，我们已经实现了RAG管道的核心组件，包括文档处理、问答和重排序。现在，我们将这些组件组合起来创建一个完整的RAG管道。

# %%
def rag_with_reranking(
    query, vector_store, reranking_method="llm", top_n=3, model="qwen-plus"
):
    """
    完整的RAG管道，包含重排序步骤。

    参数:
        query (str): 用户查询
        vector_store (SimpleVectorStore): 向量存储
        reranking_method (str): 重排序方法（'llm' 或 'keywords'）
        top_n (int): 重排序后返回的结果数量
        model (str): 回复生成模型

    返回:
        Dict: 包括查询、上下文和回复的结果字典
    """
    # 创建查询嵌入
    query_embedding = create_embeddings(query)

    # 初始检索（获取比需要的多的结果用于重排序）
    initial_results = vector_store.similarity_search(query_embedding, k=10)

    # 应用重排序
    if reranking_method == "llm":
        reranked_results = rerank_with_llm(query, initial_results, top_n=top_n)
    elif reranking_method == "keywords":
        reranked_results = rerank_with_keywords(query, initial_results, top_n=top_n)
    # ▼▼▼ 需要补充这段逻辑 ▼▼▼
    elif reranking_method == "qwen_model":
        # 调用我们之前定义的专属大模型重排函数
        reranked_results = qwen_model_rerank(
            query, initial_results, top_n=3, model="qwen-rerank"
        )
    # ▲▲▲ 补充结束 ▲▲▲

    else:
        # 没有重排序，直接使用初始检索的前N个结果
        reranked_results = initial_results[:top_n]

    # 组合重排序结果的上下文
    context = "\n\n===\n\n".join([result["text"] for result in reranked_results])

    # 基于上下文生成回复
    response = generate_response(query, context, model)

    return {
        "query": query,
        "reranking_method": reranking_method,
        "initial_results": initial_results[:top_n],
        "reranked_results": reranked_results,
        "context": context,
        "response": response,
    }

# %% [markdown]
# ## 重排序质量评估

# %%
# 从JSON文件中加载验证数据  
with open('data/val.json') as f:  
    data = json.load(f)  

# 从验证数据中提取第一个查询  
query = data[2]['question']  

# 从验证数据中提取参考答案  
reference_answer = data[2]['ideal_answer']  

# pdf_path  
pdf_path = "data/2024年AI行业报告.pdf"

# %%
# 处理文档
vector_store = process_document(pdf_path)


# 比较不同的方法
print("Comparing retrieval methods...")

# 1. 标准检索（无重排序）
print("\n=== STANDARD RETRIEVAL ===")
standard_results = rag_with_reranking(query, vector_store, reranking_method="none")
print(f"\nQuery: {query}")
print(f"\nResponse:\n{standard_results['response']}")

# 2. 基于LLM的重排序
print("\n=== LLM-BASED RERANKING ===")
llm_results = rag_with_reranking(query, vector_store, reranking_method="llm")
print(f"\nQuery: {query}")
print(f"\nResponse:\n{llm_results['response']}")

# 3. 基于关键词的重排序
print("\n=== KEYWORD-BASED RERANKING ===")
keyword_results = rag_with_reranking(query, vector_store, reranking_method="keywords")
print(f"\nQuery: {query}")
print(f"\nResponse:\n{keyword_results['response']}")

# 4. 基于专属模型 (Qwen3-Rerank) 的重排序
print("\n=== QWEN-RERANK MODEL RERANKING ===")
# 这里我们传入一个新的 reranking_method 名称，比如 "qwen_model"
model_results = rag_with_reranking(query, vector_store, reranking_method="qwen3-rerank")
print(f"\nQuery: {query}")
print(f"\nResponse:\n{model_results['response']}")
# Out:
# Extracting text from PDF...
# Chunking text...
# Created 34 text chunks
# Creating embeddings for chunks...
# Added 34 chunks to the vector store
# Comparing retrieval methods...
#
# === STANDARD RETRIEVAL ===
#
# Query: 中国政府对AI大模型发展有哪些支持政策？
#
# Response:
# 根据所提供的上下文内容，中国政府对AI大模型发展的支持政策主要包括**国家层面顶层设计与战略部署**以及**地方政府因地制宜出台的专项政策措施**两大维度，具体如下：
#
# ---
#
# ### 一、国家层面政策支持（顶层设计与宏观引导）
#
# 1. **《新一代人工智能发展规划》（2017年，国务院发布）**
#    - 是我国人工智能发展的纲领性文件，为包括大模型在内的AI技术发展提供了长期战略指引和顶层设计。
#
# 2. **《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》（2022年，科技部等六部门印发）**
#    - 落实《新一代人工智能发展规划》，强调以场景驱动AI应用落地，为大模型在行业中的规模化应用提供政策支撑。
#
# 3. **2024年《政府工作报告》提出“人工智能+”行动**
#    - 将人工智能（含大模型）上升为国家战略行动，推动其与实体经济、社会民生等深度融合，强化大模型赋能千行百业的政策导向。
#
# ---
#
# ### 二、地方政府专项支持政策（覆盖多省市，聚焦差异化发展路径）
#
# 截至2023年，北京、深圳、杭州、成都、福建、安徽、上海、广东等地均已出台针对AI大模型的专项政策，核心支持方向包括：
#
# #### ✅ **1. 北京市**
# - 发布《北京市加快建设具有全球影响力的人工智能创新策源地实施方案（2023–2025年）》《北京市促进通用人工智能创新发展的若干措施》
#   - **技术创新**：支持分布式高效深度学习框架、大模型新型基础架构等基础平台技术突破；
#   - **生态构建**：打造高效协同的大模型技术产业生态；
#   - **开源开放**：建设大模型算法及工具开源开放平台；
#   - **自主可控**：组建全栈国产化人工智能创新联合体，研发全栈国产化生成式大模型；
#   - **算力保障**：加快海淀区、朝阳区人工智能公共算力中心和数字经济算力中心建设，支撑千亿级参数大模型研发；
#   - **关键技术攻关**：开展模型构建、训练、调优对齐、推理部署等全链条研究，研发百亿参数模型端侧部署技术。
#
# #### ✅ **2. 上海市**
# - 发布《上海市推动人工智能大模型创新发展若干措施（2023–2025年）》
#   - **国际竞争力**：支持打造具备国际竞争力的大模型；
#   - **创新扶持**：实施大模型创新扶持计划，对重大成果给予专项奖励；
#   - **数据飞轮机制**：鼓励形成“数据—模型—应用—反馈”闭环，加速模型迭代；
#   - **示范应用**：在智能制造、生物医药、集成电路、智能化教育、科技金融、设计创意、自动驾驶、机器人、数字政府等领域打造标杆性大模型产品和服务。
#
# #### ✅ **3. 深圳市**
# - 重点支持：
#   - 打造基于**国内外芯片和算法的开源通用大模型**；
#   - 支持重点企业持续研发和迭代**商用通用大模型**。
#
# #### ✅ **4. 成都市**
# - 发布《成都市加快大模型创新应用推进人工智能产业高质量发展的若干措施》
#   - **技术创新**：着力推动CV（计算机视觉）、NLP（自然语言处理）、多模态大模型等基础领域研发与迭代；
#   - **行业应用**：重点布局医疗、金融、商务、交通等垂直行业大模型。
#
# #### ✅ **5. 杭州市**
# - 支持：
#   - **头部企业**开展多模态通用大模型关键技术攻关；
#   - **中小企业**深耕垂直领域，做精专用模型。
#
# #### ✅ **6. 安徽省**
# - 发布《安徽省人民政府关于印发打造通用人工智能产业创新和应用高地若干政策的通知》
#   - **资源匹配**：对落户安徽的通用及行业大模型企业、跨领域应用企业、新兴算力企业、安全AI企业等，优先匹配**算力、数据、场景、基金、场地**等要素资源。
#
# #### ✅ **7. 福建省**
# - 发布《福建省促进人工智能产业发展十条措施》
#   - **普惠算力**：以低成本、高可用的普惠算力降低企业研发成本，支撑自然语言、多模态认知等超大规模智能模型的开发与训练。
#
# #### ✅ **8. 广东省**
# - 发布《广东省人民政府关于加快建设通用人工智能产业创新引领地的实施意见》
#   - **技术体系**：围绕基础架构、训练算法、调优对齐、推理部署等环节，研发**千亿级参数通用大模型**，构建自主可控的完整技术体系；
#   - **垂直融合**：聚焦智能经济、智能社会等场景，研发**多模态数据与知识深度融合的垂直领域大模型**，支撑多任务复杂行业应用。
#
# ---
#
# ### 三、政策共性特征总结（贯穿各级政策）
#
# - **强算力支撑**：多地明确建设公共算力中心，保障大模型训练与推理所需高性能算力；
# - **重技术创新**：聚焦基础架构、训练算法、指令微调、人类意图对齐、端侧部署等关键技术；
# - **推开源开放**：鼓励建设开源平台、工具链和模型库，降低开发者门槛；
# - **促生态协同**：推动“政产学研用”协同，构建从芯片、框架、模型到应用的全栈生态；
# - **分类施策**：既支持通用大模型研发，也大力扶持医疗、金融、制造等垂直行业专用模型；
# - **强调自主可控与安全可信**：突出国产软硬件适配、全栈自主、数据安全与内容可控。
#
# ---
#
# 综上，中国政府已构建起“国家统筹—地方联动—多维协同”的立体化政策支持体系，覆盖战略引导、技术研发、算力基建、开源生态、行业应用、资源保障与安全治理等全链条环节，全面助推AI大模型产业高质量发展。
#
# === LLM-BASED RERANKING ===
# Reranking 10 documents...
# Scoring document 1/10...
# Scoring document 6/10...
# Building prefix dict from the default dictionary ...
# Query: 中国政府对AI大模型发展有哪些支持政策？
#
# Response:
# 根据所提供的上下文内容，中国政府对AI大模型发展的支持政策可从**国家层面顶层设计**和**地方政府具体举措**两个维度进行全面梳理，具体如下：
#
# ---
#
# ### 一、国家层面政策支持（顶层设计与战略引导）
#
# 1. **《新一代人工智能发展规划》（2017年，国务院发布）**
#    - 是我国人工智能发展的纲领性文件，为AI大模型等前沿技术发展奠定战略基础。
#
# 2. **《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》（2022年，科技部等六部门印发）**
#    - 明确提出以“场景驱动”推动人工智能高水平应用，落实《新一代人工智能发展规划》，为大模型在行业落地提供政策依据和实施路径。
#
# 3. **2024年《政府工作报告》提出开展“人工智能+”行动**
#    - 将人工智能（含大模型）上升为国家战略行动，强调与千行百业深度融合，拓展大模型应用场景，强化其赋能实体经济的能力。
#
# ---
#
# ### 二、地方政府层面政策支持（聚焦大模型技术研发、生态构建与产业落地）
#
# 截至2023—2024年，北京、上海、深圳、杭州、成都、福建、安徽、广东等地均已出台专项政策，核心方向包括：**技术创新支持、算力基础设施建设、开源生态培育、垂直行业应用推广、资源要素保障**等。具体如下：
#
# #### ✅ 北京市（2023年5月）
# - 发布两份核心政策：
#   - 《北京市加快建设具有全球影响力的人工智能创新策源地实施方案（2023–2025年）》
#     - 支持突破**分布式高效深度学习框架、大模型新型基础架构**等基础平台技术；
#     - 建设**大模型算法及工具开源开放平台**，构建完整技术创新体系；
#     - 组建**全栈国产化人工智能创新联合体**，搭建基于国产软硬件的训练与服务基础设施；
#     - 研发**全栈国产化的生成式大模型**，推动自主可控技术体系和产业生态形成。
#   - 《北京市促进通用人工智能创新发展的若干措施》
#     - **高效推动新增算力基础设施建设**：加快海淀区、朝阳区建设**北京人工智能公共算力中心、北京数字经济算力中心**，支撑千亿级参数大模型研发；
#     - **开展大模型创新算法及关键技术研究**：覆盖模型构建、训练、调优对齐、推理部署全链条，重点攻关**基础模型架构创新、高效并行训练、认知推理、指令学习、人类意图对齐、百亿参数模型端侧部署压缩技术**等。
#
# #### ✅ 上海市（2023年10月，《上海市推动人工智能大模型创新发展若干措施（2023–2025年）》）
# - 实施**大模型创新扶持计划**：支持引进高水平企业，鼓励打造**具备国际竞争力的大模型**；支持形成“数据飞轮”，加速模型迭代；对重大成果给予**专项奖励**；
# - 实施**大模型示范应用推进计划**：重点支持在**智能制造、生物医药、集成电路、智能化教育教学、科技金融、设计创意、自动驾驶、机器人、数字政府**等领域打造标杆性大模型产品和服务。
#
# #### ✅ 深圳市（政策导向明确，未列具体文件名但多次提及）
# - 重点支持打造**基于国内外芯片和算法的开源通用大模型**；
# - 支持重点企业持续研发和迭代**商用通用大模型**。
#
# #### ✅ 杭州市
# - 支持**头部企业开展多模态通用大模型关键技术攻关**；
# - 鼓励**中小企业深耕垂直领域，做精专用模型**。
#
# #### ✅ 成都市（2023年8月，《成都市加快大模型创新应用推进人工智能产业高质量发展的若干措施》）
# - 着力推动大模型相关技术创新；
# - 重点研发和迭代**CV大模型、NLP大模型、多模态大模型**；
# - 加快布局**医疗、金融、商务、交通等行业大模型**。
#
# #### ✅ 福建省（2023年9月，《福建省促进人工智能产业发展十条措施》）
# - 以**普惠算力**降低企业研发成本，支撑快速增长的算力需求；
# - 促进**自然语言、多模态认知等超大规模智能模型开发训练**。
#
# #### ✅ 安徽省（2023年10月，《安徽省打造通用人工智能产业创新和应用高地若干政策》）
# - 对在皖落户的**通用及行业大模型企业、跨领域应用企业、新兴算力企业、安全人工智能企业**，优先匹配**算力、数据、场景、基金、场地等要素资源**。
#
# #### ✅ 广东省（2023年11月，《广东省加快建设通用人工智能产业创新引领地的实施意见》）
# - 围绕**基础架构、训练算法、调优对齐、推理部署**等环节，研发**千亿级参数人工智能通用大模型**，构建自主可控的完整技术体系；
# - 聚焦**智能经济、智能社会**等创新场景，研发**多模态数据与知识深度融合的垂直领域大模型**，支撑多任务复杂场景行业应用。
#
# ---
#
# ### 三、政策共性特征总结（隐含于上下文）
#
# - **强技术导向**：普遍聚焦大模型底层架构、训练算法、推理优化、国产化适配等核心技术突破；
# - **重生态协同**：强调“产学研用”协同、开源平台建设、创新联合体组建、全栈国产化生态培育；
# - **重算力底座**：多地将公共算力中心建设列为优先任务，保障大模型训练与迭代的基础设施供给；
# - **促行业融合**：突出“AI+行业”，推动大模型在医疗、金融、交通、制造、政务等垂直领域落地；
# - **分类施策**：区分通用大模型（强调国际竞争力、自主可控）与专用/行业大模型（强调场景适配、中小企参与）。
#
# ---
#
# 综上，中国政府对AI大模型的支持已形成**国家统筹、地方联动、技术攻坚、场景牵引、生态筑基**的立体化政策体系，覆盖从基础研究、技术攻关、算力支撑、开源开放到行业应用的全生命周期。
#
# === KEYWORD-BASED RERANKING ===
# Dumping model to file cache /tmp/jieba.cache
# Loading model cost 0.784 seconds.
# Prefix dict has been built successfully.
# Query: 中国政府对AI大模型发展有哪些支持政策？
#
# Response:
# 根据提供的上下文内容，中国政府对AI大模型发展的支持政策主要包括以下三个层面：
#
# 一、**国家顶层设计与宏观政策引导**
# 1. **《新一代人工智能发展规划》（2017年，国务院发布）**：作为我国人工智能发展的纲领性文件，为包括大模型在内的AI技术长期发展奠定战略基础。
# 2. **《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》（2022年，科技部等六部门印发）**：明确要求落实《新一代人工智能发展规划》，强调通过场景驱动推动AI高水平应用，为大模型在行业落地提供政策依据和实施路径。
# 3. **2024年《政府工作报告》提出开展“人工智能+”行动**：将人工智能（含大模型）上升为国家战略行动，强化其与实体经济、社会民生各领域的深度融合，成为当前及今后一段时期的核心政策抓手。
#
# 二、**地方政府密集出台专项支持政策（截至2023–2024年）**
# 多地已发布聚焦AI大模型的专项政策，形成差异化协同发展格局：
# - **北京市**：
#   - 2023年5月发布《北京市加快建设具有全球影响力的人工智能创新策源地实施方案（2023–2025年）》：
#     ▪ 支持突破分布式高效深度学习框架、大模型新型基础架构等基础平台技术；
#     ▪ 着力推动大模型相关技术创新，构建高效协同的技术产业生态；
#     ▪ 建设大模型算法及工具开源开放平台，构建完整技术创新体系；
#     ▪ 组建全栈国产化人工智能创新联合体，搭建基于国产软硬件的训练与服务基础设施；
#     ▪ 研发全栈国产化的生成式大模型，推动自主可控技术体系和产业生态建设。
#   - 同期发布《北京市促进通用人工智能创新发展的若干措施》：
#     ▪ **算力支撑**：加快海淀区、朝阳区建设北京人工智能公共算力中心、北京数字经济算力中心，形成规模化先进算力供给能力，支撑千亿级参数大模型（如大型语言模型、视觉模型、多模态模型、科学计算模型、神经网络仿真模型、脑启发模型）研发；
#     ▪ **技术研发**：围绕模型构建、训练、调优对齐、推理部署等环节，探索基础模型架构创新；研究大模型高效并行训练技术；攻关认知推理、指令学习、人类意图对齐等调优方法；研发支持百亿参数模型推理的高效压缩与端侧部署技术。
#
# - **上海市**：强调打造具备国际竞争力的大模型，突出全球化视野与高端能级。
# - **深圳市**：重点支持打造基于国内外芯片和算法的开源通用大模型；支持重点企业持续研发和迭代商用通用大模型。
# - **安徽省**：从资源层面着手，吸引大模型企业入驻，强化产业承载能力。
# - **成都市**：着力推动大模型技术创新，重点研发和迭代CV（计算机视觉）、NLP（自然语言处理）、多模态大模型，以及面向医疗、金融、商务、交通等行业的垂直领域大模型。
# - **杭州市**：支持头部企业开展多模态通用大模型关键技术攻关；鼓励中小企业深耕垂直领域，做精专用模型。
# - **福建、广东等地**：亦已发布相关AI大模型支持政策（具体标题与内容未详述，但明确列入政策覆盖范围）。
#
# 三、**政策导向的共性重点方向（贯穿各级政策）**
# - **强化技术创新**：聚焦基础架构、训练算法、调优对齐、推理部署、端侧轻量化等关键环节；
# - **夯实算力底座**：加快公共算力中心建设，保障大规模模型训练所需先进算力；
# - **推动生态协同**：构建“产学研用”高效协同的技术产业生态，支持开源平台与国产软硬件适配；
# - **促进应用落地**：鼓励通用大模型研发与垂直行业专用模型并重，强调“通用化与专用化”双轨发展；
# - **坚持自主可控**：推进全栈国产化大模型研发，构建自主可控的人工智能技术体系和产业生态。
#
# 综上，中国政府对AI大模型的支持已形成“国家规划引领—部委指导意见落实—地方政府精准施策”的三级政策体系，覆盖战略定位、技术研发、算力基建、生态培育、行业应用与安全可控等全链条关键环节。
#
# === QWEN-RERANK MODEL RERANKING ===
#
# Query: 中国政府对AI大模型发展有哪些支持政策？
#
# Response:
# 根据所提供的上下文内容，中国政府对AI大模型发展的支持政策主要包括**国家层面顶层设计与战略部署**以及**地方政府因地制宜出台的专项政策措施**两大维度，具体如下：
#
# ---
#
# ### 一、国家层面政策支持（顶层设计与宏观引导）
#
# 1. **《新一代人工智能发展规划》（2017年，国务院发布）**
#    - 是我国人工智能发展的纲领性文件，为包括大模型在内的AI技术发展提供了长期战略指引和顶层设计。
#
# 2. **《关于加快场景创新以人工智能高水平应用促进经济高质量发展的指导意见》（2022年，科技部等六部门印发）**
#    - 落实《新一代人工智能发展规划》，强调以场景驱动AI应用落地，为大模型在行业中的规模化应用提供政策支撑。
#
# 3. **2024年《政府工作报告》提出“人工智能+”行动**
#    - 将人工智能（含大模型）上升为国家战略行动，推动其与实体经济、社会民生等深度融合，强化大模型赋能千行百业的政策导向。
#
# ---
#
# ### 二、地方政府专项支持政策（覆盖多省市，聚焦差异化发展路径）
#
# 截至2023年，北京、深圳、杭州、成都、福建、安徽、上海、广东等地均已出台针对AI大模型的专项政策，核心支持方向包括：
#
# #### ✅ **1. 北京市**
# - 发布《北京市加快建设具有全球影响力的人工智能创新策源地实施方案（2023–2025年）》《北京市促进通用人工智能创新发展的若干措施》
#   - **技术创新**：支持分布式高效深度学习框架、大模型新型基础架构等基础平台技术突破；
#   - **生态构建**：打造高效协同的大模型技术产业生态；
#   - **开源开放**：建设大模型算法及工具开源开放平台；
#   - **自主可控**：组建全栈国产化人工智能创新联合体，研发全栈国产化生成式大模型；
#   - **算力保障**：加快海淀区、朝阳区人工智能公共算力中心和数字经济算力中心建设，支撑千亿级参数大模型研发；
#   - **关键技术攻关**：开展模型构建、训练、调优对齐、推理部署等全链条研究，研发百亿参数模型端侧部署技术。
#
# #### ✅ **2. 上海市**
# - 发布《上海市推动人工智能大模型创新发展若干措施（2023–2025年）》
#   - **国际竞争力**：支持打造具备国际竞争力的大模型；
#   - **创新扶持**：实施大模型创新扶持计划，对重大成果给予专项奖励；
#   - **数据飞轮机制**：鼓励形成“数据—模型—应用—反馈”闭环，加速模型迭代；
#   - **示范应用**：在智能制造、生物医药、集成电路、智能化教育、科技金融、设计创意、自动驾驶、机器人、数字政府等领域打造标杆性大模型产品和服务。
#
# #### ✅ **3. 深圳市**
# - 重点支持：
#   - 打造基于**国内外芯片和算法的开源通用大模型**；
#   - 支持重点企业持续研发和迭代**商用通用大模型**。
#
# #### ✅ **4. 成都市**
# - 发布《成都市加快大模型创新应用推进人工智能产业高质量发展的若干措施》
#   - **技术创新**：着力推动CV（计算机视觉）、NLP（自然语言处理）、多模态大模型等基础领域研发与迭代；
#   - **行业应用**：重点布局医疗、金融、商务、交通等垂直行业大模型。
#
# #### ✅ **5. 杭州市**
# - 支持：
#   - **头部企业**开展多模态通用大模型关键技术攻关；
#   - **中小企业**深耕垂直领域，做精专用模型。
#
# #### ✅ **6. 安徽省**
# - 发布《安徽省人民政府关于印发打造通用人工智能产业创新和应用高地若干政策的通知》
#   - **资源匹配**：对落户安徽的通用及行业大模型企业、跨领域应用企业、新兴算力企业、安全AI企业等，优先匹配**算力、数据、场景、基金、场地**等要素资源。
#
# #### ✅ **7. 福建省**
# - 发布《福建省促进人工智能产业发展十条措施》
#   - **普惠算力**：以低成本、高可用的普惠算力降低企业研发成本，支撑自然语言、多模态认知等超大规模智能模型的开发与训练。
#
# #### ✅ **8. 广东省**
# - 发布《广东省人民政府关于加快建设通用人工智能产业创新引领地的实施意见》
#   - **技术体系**：围绕基础架构、训练算法、调优对齐、推理部署等环节，研发**千亿级参数通用大模型**，构建自主可控的完整技术体系；
#   - **垂直融合**：聚焦智能经济、智能社会等场景，研发**多模态数据与知识深度融合的垂直领域大模型**，支撑多任务复杂行业应用。
#
# ---
#
# ### 三、政策共性特征总结（贯穿各级政策）
#
# - **强算力支撑**：多地明确建设公共算力中心，保障大模型训练与推理所需高性能算力；
# - **重技术创新**：聚焦基础架构、训练算法、指令微调、人类意图对齐、端侧部署等关键技术；
# - **推开源开放**：鼓励建设开源平台、工具链和模型库，降低开发者门槛；
# - **促生态协同**：推动“政产学研用”协同，构建从芯片、框架、模型到应用的全栈生态；
# - **分类施策**：既支持通用大模型研发，也大力扶持医疗、金融、制造等垂直行业专用模型；
# - **强调自主可控与安全可信**：突出国产软硬件适配、全栈自主、数据安全与内容可控。
#
# ---
#
# 综上，中国政府已构建起“国家统筹—地方联动—多维协同”的立体化政策支持体系，覆盖战略引导、技术研发、算力基建、开源生态、行业应用、资源保障与安全治理等全链条环节，全面助推AI大模型产业高质量发展。

# %%
def evaluate_reranking(query, standard_results, reranked_results, reference_answer=None):
    """
    对比重新排序结果与标准结果的质量。

    参数:
        query (str): 用户查询
        standard_results (Dict): 标准检索的结果
        reranked_results (Dict): 重新排序检索的结果
        reference_answer (str, optional): 用于比较的参考答案

    返回:
        str: 评估输出
    """
    # 中文系统提示
    system_prompt = (
        "你是一名RAG系统的专家评测员。"
        "请比较两种不同检索方式得到的上下文和回答，评估哪种方式提供了更优质的上下文和更准确、全面的答案。"
    )
    
    # 准备包含截断上下文和回答的对比文本
    comparison_text = f"""查询：{query}

标准检索方式返回的上下文：
{standard_results['context'][:1000]}... [已截断]

标准检索方式的回答：
{standard_results['response']}

重排序检索方式返回的上下文：
{reranked_results['context'][:1000]}... [已截断]

重排序检索方式的回答：
{reranked_results['response']}"""

    # 如果提供了参考答案，则将其包含在对比文本中
    if reference_answer:
        comparison_text += f"""

参考答案：
{reference_answer}"""

    # 中文用户提示
    user_prompt = f"""
{comparison_text}

请从以下几个方面进行评价：
1. 哪种方式提供了更相关的上下文
2. 哪种方式给出了更准确的答案
3. 哪种方式的答案更全面
4. 总体上哪种方式表现更好

请结合具体内容，给出详细分析和理由。
"""
    
    # 使用指定模型生成评估回复
    response = client.chat.completions.create(
        model="qwen-plus",
        temperature=0,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": user_prompt}
        ]
    )
    
    # 返回评估输出
    return response.choices[0].message.content

# %%
# 评估重新排序结果与标准结果的质量
evaluation = evaluate_reranking(
    query=query,  # 用户查询
    standard_results=standard_results,  # 标准检索结果
    reranked_results=llm_results,  # 基于LLM的重新排序结果
    reference_answer=reference_answer  # 用于比较的参考答案
)

# 打印评估结果
print("\n=== EVALUATION RESULTS ===")
print(evaluation)
# Out:
# === EVALUATION RESULTS ===
# 我们从四个维度对**标准检索方式**与**重排序检索方式**在回答“中国政府对AI大模型发展有哪些支持政策？”这一查询时的表现进行系统性、证据驱动的对比分析。所有判断均严格基于所提供的上下文片段、生成的回答内容及参考答案（简洁版标准答案）。
#
# ---
#
# ### ✅ 1. 哪种方式提供了更相关的上下文？
#
# **→ 重排序检索方式明显更相关。**
#
# #### 理由分析：
# - **标准检索上下文**：
#   - 虽然开头提到了《新一代人工智能发展规划》《指导意见》《政府工作报告》“人工智能+”行动，以及北京、上海等8地政策存在，但**关键细节被严重截断或缺失**。例如：
#     - 北京两份政策文件名仅出现前半部分（如“《北京市加快建设……实施方案（2023–2025年）》”），无完整标题；
#     - 政策内容高度概括（如“北京着力推动技术创新”“上海强调打造国际竞争力”），**缺乏具体措施、技术方向、时间节点、资源保障等实质性信息**；
#     - 后续章节（如4.1–4.4）聚焦产业趋势（云/端侧、通用/专用、开源、芯片），**与“政策支持”这一查询意图弱相关甚至无关**，属于干扰信息。
#   - 上下文结构松散，页码混乱（如“1/37”“2/37”），疑似PDF原始分页切片，未做语义去噪与主题聚类。
#
# - **重排序检索上下文**：
#   - **精准锚定政策文本本身**：不仅列出8省市名称，还明确标注了**发布时间、发布机构、政策全称、结构化政策内容条目**（如“高效推动新增算力基础设施建设”“开展大模型创新算法及关键技术研究”）；
#   - **关键细节完整保留**：如北京两份政策的差异化定位（策源地方案 vs 若干措施）、上海“数据飞轮”机制、成都CV/NLP/多模态分类、安徽“算力/数据/场景/基金/场地五要素匹配”、广东“千亿参数+多模态知识融合”等——**全部是直接支撑“政策支持”的高价值事实**；
#   - **时间线索清晰**：2023年5月（北京）、10月（上海）、8月（成都）、9月（福建）、11月（广东）等，体现政策演进脉络，增强可信度与时效性；
#   - **无冗余趋势分析段落**：剔除了标准检索中大量关于“C端用户成主客群”“高性能芯片升级”等非政策类产业展望内容，**上下文纯度更高、信噪比更强**。
#
# ✅ **结论**：重排序上下文经过语义重排与关键信息强化，显著提升与查询意图（“支持政策”）的相关性与信息密度；标准检索上下文则混杂背景、趋势、结论等非政策内容，相关性较弱。
#
# ---
#
# ### ✅ 2. 哪种方式给出了更准确的答案？
#
# **→ 重排序检索方式更准确。**
#
# #### 理由分析：
# 准确性 = 回答是否忠实反映上下文事实，有无虚构、夸大、错配或张冠李戴。
#
# - **标准检索回答中的准确性风险**：
#   - 将**未在上下文中出现的政策文件名补全为完整标题**（如《北京市促进通用人工智能创新发展的若干措施》），虽合理，但原文仅显示“《北京市促进通用人工智能创新发展...》”，属**合理推断但非严格忠实**；
#   - 对**上海政策中“数据飞轮机制”“示范应用领域列表”** 的描述，在标准上下文中**完全未出现**（原文只写“上海强调打造具备国际竞争力的大模型”），属于**无依据添加**；
#   - 将**福建“普惠算力”解读为“以低成本、高可用的普惠算力降低企业研发成本”**，虽语义接近，但原文仅说“以低成本、高可用的普惠算力降低企业研发成本，支撑……开发与训练”，标准回答却误写为“**支撑自然语言、多模态认知等超大规模智能模型的开发与训练**”——而原文实际是“**支撑自然语言、多模态认知等超大规模智能模型的开发与训练**” ✅（此处需修正：该句其实在重排序上下文中也出现了，见福建段；但标准回答中该句是**正确复现**的，暂不构成错误）；
#   - 更严重的是：**将安徽省政策概括为“优先匹配算力、数据、场景、基金、场地等要素资源”**，该表述在标准上下文中**完全未出现**（原文只写“安徽从资源方面着手吸引大模型企业入驻”），属于**过度发挥、无文本依据的编造**。
#
# - **重排序检索回答的准确性表现**：
#   - 所有政策名称、发布时间、发布机构、核心举措均**严格对应上下文所列内容**，如：
#     - 明确指出北京两份政策分别发布于“2023年5月”，并分别引用其原文小标题（“高效推动新增算力基础设施建设”“开展大模型创新算法及关键技术研究”）；
#     - 上海政策中“数据飞轮”“专项奖励”“九大示范领域”等，均在重排序上下文中**有明确出处**（“鼓励形成‘数据—模型—应用—反馈’闭环”“对重大成果给予专项奖励”“智能制造、生物医药……数字政府”）；
#     - 安徽省“算力、数据、场景、基金、场地”五要素，**原文即为“优先匹配算力、数据、场景、基金、场地等要素资源”**，一字不差；
#     - 广东省“千亿级参数通用大模型”“多模态数据与知识深度融合的垂直领域大模型”，亦为原文直引。
#
# ✅ **结论**：重排序回答严格遵循“所见即所得”原则，未引入任何上下文外信息；标准回答存在多处**无依据扩展、细节捏造、政策错配**，准确性明显偏低。
#
# ---
#
# ### ✅ 3. 哪种方式的答案更全面？
#
# **→ 二者在广度上接近，但重排序方式在深度与结构性上更优，整体更全面。**
#
# #### 广度对比（覆盖政策层级/地域/类型）：
# | 维度 | 标准检索回答 | 重排序检索回答 | 评价 |
# |------|----------------|-------------------|------|
# | 国家层面政策 | ✔️ 3项（2017规划、2022指导意见、2024“人工智能+”） | ✔️ 同上，且强调“落实路径”“实施路径” | 持平 |
# | 地方省市数量 | ✔️ 8个（京沪深杭成闽皖粤） | ✔️ 同样8个，且**全部标注发布时间与政策全称** | 重排序胜（信息更结构化） |
# | 政策类型覆盖 | ✔️ 技术创新、算力、开源、行业应用、安全可控 | ✔️ 同上，且补充**资源要素保障（安徽）、普惠算力（福建）、端侧部署（北京）**等细分维度 | 重排序略优 |
#
# #### 深度与结构性对比：
# - **标准回答**：
#   - 将各省市政策归纳为“✅ 1. 北京市”“✅ 2. 上海市”…形式，**但内部结构松散**，如北京段虽列6点，但部分为泛泛而谈（如“生态构建”“开源开放”），缺乏与上下文强对应的动词短语（如“建设公共算力中心”“研发百亿参数端侧部署技术”）；
#   - “政策共性特征总结”部分使用主观概括词汇（如“强算力支撑”“重技术创新”），**未锚定具体政策原文措辞**，抽象度高、落地感弱。
#
# - **重排序回答**：
#   - **每项地方政策均按“政策名称+发布时间+原文小标题+原文要点”三级结构展开**，如北京段明确区分“策源地方案”与“若干措施”，并分别对应不同原文段落；
#   - 关键技术术语**全部来自上下文原文**：“认知推理、指令学习、人类意图对齐、百亿参数模型端侧部署压缩技术”——这些在标准上下文中根本未出现，却在重排序上下文中完整保留；
#   - “政策共性特征总结”部分用词更精准（如“强技术导向”“重生态协同”），且每条后紧跟**上下文中的原生例证**（如“全栈国产化生态培育”对应北京“全栈国产化创新联合体”），**虚实结合、论据扎实**。
#
# ✅ **结论**：二者覆盖范围相当，但重排序回答在**政策细节颗粒度、原文依存度、结构逻辑性**上全面占优，因此更具实质性的“全面性”。
#
# ---
#
# ### ✅ 4. 总体上哪种方式表现更好？
#
# **→ 重排序检索方式全面优于标准检索方式。**
#
# | 维度 | 表现 | 原因总结 |
# |------|------|-----------|
# | **相关性** | ⭐⭐⭐⭐⭐ | 上下文聚焦政策原文，剔除趋势/预测等干扰信息，信噪比高 |
# | **准确性** | ⭐⭐⭐⭐⭐ | 严格忠实原文，零虚构、零错配、零张冠李戴 |
# | **全面性** | ⭐⭐⭐⭐☆ | 广度持平，深度与结构显著更优；唯一短板是未显式提及“安全治理”（但上下文本身也未提，非方法缺陷） |
# | **可验证性 & 可追溯性** | ⭐⭐⭐⭐⭐ | 每一条主张均可回溯至上下文中的具体句子、政策名称、发布时间，审计友好 |
# | **用户价值** | ⭐⭐⭐⭐⭐ | 用户可直接依据回答定位政策原文、理解政策工具箱（如“算力中心”“开源平台”“数据飞轮”），具备实操参考价值 |
#
# ⚠️ **标准检索方式的核心缺陷**：
# 它本质上是“关键词粗筛 + 通用模板填充”，未对碎片化PDF文本做语义清洗、主题聚类与关键信息提取，导致：
# - 上下文混杂无关内容 → 相关性低；
# - LLM被迫“脑补”缺失细节 → 准确性受损；
# - 结构扁平、缺乏原文锚点 → 全面性流于表面。
#
# 🎯 **重排序方式的本质优势**：
# 它通过**语义重排序（Semantic Re-ranking）+ 关键信息增强（Key Fact Augmentation）+ 结构化抽取（Policy Name/Time/Agency/Content）**，将原始噪声文本转化为高保真政策知识图谱，使RAG真正实现“**查得准、答得实、展得清**”。
#
# ---
#
# ### ✅ 最终结论：
#
# | 评估项 | 胜出方式 | 简明理由 |
# |----------|------------|-------------|
# | **更相关的上下文** | ✅ 重排序检索 | 聚焦政策原文，剔除趋势/预测等无关内容，信息密度高 |
# | **更准确的答案** | ✅ 重排序检索 | 严格忠实上下文，无虚构、无错配、无过度推断 |
# | **更全面的答案** | ✅ 重排序检索 | 广度相当，但深度（技术细节、原文措辞、结构层次）显著更优 |
# | **总体表现** | ✅✅✅ 重排序检索 | 在RAG系统的核心目标——**精准、可靠、可解释地响应专业政策查询**——上实现全面领先 |
#
# 📌 **建议**：在面向政策、法规、标准等高可靠性要求的垂直领域RAG系统中，**必须采用具备语义重排序与结构化信息抽取能力的检索增强策略**，而非依赖传统BM25/Embedding粗检。本案例是重排序技术价值的典型实证。
#
# ---
#
# 如需，我可进一步提供：
# - 重排序模块的技术实现建议（如Cross-Encoder微调、Policy-BERT设计）；
# - 如何将此类政策文本构建成结构化知识库（JSON Schema示例）；
# - 面向政务问答场景的评估指标体系（Policy-F1, Source Traceability Score等）。
#
# 欢迎继续深入探讨。
